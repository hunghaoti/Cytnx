# %% [markdown]
# ## Cytnx tutorial on colab
# See https://cytnx-dev.github.io/Cytnx_doc/v1.0.0/index.html for more information of the Cytnx library

# %% [markdown]
# Install `conda` on `colab` and install `Cytnx`

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# %%bash
# conda init
# conda config --add channels conda-forge
# conda create --channel conda-forge --name cytnx python=3.11 _openmp_mutex=*=*_llvm
# conda activate cytnx
# conda install -c kaihsinwu cytnx
# Out:
# no change     /usr/local/condabin/conda
# no change     /usr/local/bin/conda
# no change     /usr/local/bin/conda-env
# no change     /usr/local/bin/activate
# no change     /usr/local/bin/deactivate
# no change     /usr/local/etc/profile.d/conda.sh
# no change     /usr/local/etc/fish/conf.d/conda.fish
# no change     /usr/local/shell/condabin/Conda.psm1
# no change     /usr/local/shell/condabin/conda-hook.ps1
# no change     /usr/local/lib/python3.11/site-packages/xontrib/conda.xsh
# no change     /usr/local/etc/profile.d/conda.csh
# no change     /root/.bashrc
# No action taken.
# Channels:
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/cytnx
#
#   added / updated specs:
#     - _openmp_mutex[build=*_llvm]
#     - python=3.11
#
#
# The following NEW packages will be INSTALLED:
#
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-3_kmp_llvm
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h4bc722e_7
#   ca-certificates    conda-forge/noarch::ca-certificates-2025.4.26-hbd8a1cb_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.43-h712a8e2_4
#   libexpat           conda-forge/linux-64::libexpat-2.7.0-h5888daf_0
#   libffi             conda-forge/linux-64::libffi-3.4.6-h2dba641_1
#   libgcc             conda-forge/linux-64::libgcc-14.2.0-h767d61c_2
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-14.2.0-h69a702a_2
#   liblzma            conda-forge/linux-64::liblzma-5.8.1-hb9d3cd8_0
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libsqlite          conda-forge/linux-64::libsqlite-3.49.1-hee588c1_2
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.3.1-hb9d3cd8_2
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-20.1.3-h024ca30_0
#   ncurses            conda-forge/linux-64::ncurses-6.5-h2d0b736_3
#   openssl            conda-forge/linux-64::openssl-3.5.0-h7b32b05_0
#   pip                conda-forge/noarch::pip-25.1-pyh8b19718_0
#   python             conda-forge/linux-64::python-3.11.12-h9e4cc4f_0_cpython
#   readline           conda-forge/linux-64::readline-8.2-h8c095d6_2
#   setuptools         conda-forge/noarch::setuptools-79.0.1-pyhff2d567_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   tzdata             conda-forge/noarch::tzdata-2025b-h78e105d_0
#   wheel              conda-forge/noarch::wheel-0.45.1-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages: ...working... done
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate cytnx
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Channels:
#  - kaihsinwu
#  - conda-forge
# Platform: linux-64
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
# Warning: 'conda-forge' already in 'channels' list, moving to the top
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# CondaError: Run 'conda init' before 'conda activate'
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda

# %%
import sys
import cytnx
import numpy as np
import matplotlib.pyplot as plt
# Out:
# /usr/local/lib/python3.11/site-packages/cytnx/__init__.py:14: UserWarning: numpy and/or scipy are imported before cytnx. Please make sure it support ILP64.
#   warnings.warn("numpy and/or scipy are imported before cytnx. Please make sure it support ILP64.")

# %%
# test
A = cytnx.ones(4)
print(A)
# Out:
# Total elem: 4
# type  : Double (Float64)
# cytnx device: CPU
# Shape : (4)
# [1.00000e+00 1.00000e+00 1.00000e+00 1.00000e+00 ]

# %% [markdown]
# # Density matrix renormalization group (DMRG) tutorail

# %% [markdown]
# ## 1. Define the matrix product operator (MPO) for the Hamiltonian

# %% [markdown]
# ### 1.1 Define operators

# %% [markdown]
# #### $$ \hat{S}^{+}=\left[\begin{array}{cc}
# 0 & 1\\
# 0 & 0
# \end{array}\right]
# , \qquad
# \hat{S}^{-}=\left[\begin{array}{cc}
# 0 & 0\\
# 1 & 0
# \end{array}\right]$$
# #### $$ \hat{S}^{z}=\frac{1}{2}\left[\begin{array}{cc}
# 1 & 0\\
# 0 & -1
# \end{array}\right]
# , \qquad
# \hat{S}^{x}=\frac{1}{2}\left[\begin{array}{cc}
# 0 & 1\\
# 1 & 0
# \end{array}\right]
# , \qquad
# \hat{I}=\left[\begin{array}{cc}
# 1 & 0\\
# 0 & 1
# \end{array}\right]
# $$

# %% [markdown]
# <!-- ![alt text](szsx.png "Title") -->
# <img src="https://github.com/Cytnx-dev/Cytnx_colab_tutorial/blob/main/figures/szsx.png?raw=1" alt="drawing" width="300"/>

# %%
Nsites = 20 # Number of sites
chi = 32 # MPS bond dimension
d = 2 #physical dimension
s = 0.5 #spin-half

sx = cytnx.physics.spin(0.5,'x')
sy = cytnx.physics.spin(0.5,'y')
sp = sx+1j*sy
sm = sx-1j*sy
eye = cytnx.eye(d)

# %% [markdown]
# ### 1.2 Define Hamiltonian MPO

# %% [markdown]
# #### XX model
# #### MPO tensor
# #### $$\hat{H} = L_0 M_1 M_2 \cdots M_N R_0,$$
# #### $$
# L_{0}=\left[\begin{array}{ccc}
# 0 & 0 & 1\end{array}\right]
# , \qquad
# M_i=\left[\begin{array}{ccc}
# \hat{I_i}& \sqrt{2} \hat{S}^{+}_i & \sqrt{2} \hat{S}^{-}_i & 0\\
# 0 & 0 & 0&\sqrt{2} \hat{S}^{-}_i\\
# 0 & 0& 0 & \sqrt{2} \hat{S}^{+}_i\\
# 0 & 0& 0 & \hat{I_i}
# \end{array}\right]
# , \qquad
# R_{0}=\left[\begin{array}{c}
# 1\\
# 0\\
# 0
# \end{array}\right]
# $$

# %% [markdown]
# <img src="https://github.com/Cytnx-dev/Cytnx_colab_tutorial/blob/main/figures/mpo.png?raw=1" alt="drawing" width="600"/>

# %%
M = cytnx.zeros([4, 4, d, d])
M[0,0] = M[3,3] = eye
M[0,1] = M[2,3] = 2**0.5*sp.real()
M[0,2] = M[1,3] = 2**0.5*sm.real()
M = cytnx.UniTensor(M,0)

L0 = cytnx.UniTensor(cytnx.zeros([4,1,1]), rowrank = 0) #Left boundary
R0 = cytnx.UniTensor(cytnx.zeros([4,1,1]), rowrank = 0) #Right boundarM = y
L0[0,0,0] = 1.; R0[3,0,0] = 1.

# %% [markdown]
# ## 2. Initialize MPS

# %% [markdown]
# ### 2.1 Initialize MPS as a random state

# %% [markdown]
# <img src="https://github.com/Cytnx-dev/Cytnx_colab_tutorial/blob/main/figures/mps.png?raw=1" alt="drawing" width="450"/>

# %%
# Initialize MPS as a product state
lbls = [] # List for storing the MPS labels
A = [None for i in range(Nsites)]
A[0] = cytnx.UniTensor(cytnx.random.normal([1, d, min(chi, d)], 0., 1.), rowrank = 2)
A[0].relabels_(["0","1","2"])
lbls.append(["0","1","2"]) # store the labels for later convinience.

for k in range(1,Nsites):
    dim1 = A[k-1].shape()[2]; dim2 = d
    dim3 = min(min(chi, A[k-1].shape()[2] * d), d ** (Nsites - k - 1))
    A[k] = cytnx.UniTensor(cytnx.random.normal([dim1, dim2, dim3],0.,1.), rowrank = 2)

    lbl = [str(2*k),str(2*k+1),str(2*k+2)]
    A[k].relabels_(lbl)
    lbls.append(lbl) # store the labels for later convinience.

# %% [markdown]
# ## 3. Define the effective Hamiltonian

# %% [markdown]
# ### 3.1 Compute the environment tensors LR, and make the MPS **left orthogonal**

# %% [markdown]
# <img src="https://github.com/Cytnx-dev/Cytnx_colab_tutorial/blob/main/figures/leftotho.png?raw=1" alt="drawing" width="700"/>
# <img src="https://github.com/Cytnx-dev/Cytnx_colab_tutorial/blob/main/figures/envcontract.png?raw=1" alt="drawing" width="400"/>

# %%
#LR[0]:        LR[1]:            LR[2]:
#
#   -----      -----A[0]---     -----A[1]---
#   |          |     |          |     |
#  ML----     LR[0]--M-----    LR[1]--M-----      ......
#   |          |     |          |     |
#   -----      -----A*[0]--     -----A*[1]--
#
#
LR = [None for i in range(Nsites+1)]
LR[0]  = L0
LR[-1] = R0
for p in range(Nsites - 1):

    ## Changing to canonical form site by site:
    s, A[p] ,vt = cytnx.linalg.Gesvd(A[p])
    A[p+1] = cytnx.Contract(cytnx.Contract(s,vt),A[p+1])

    ## Calculate enviroments:
    anet = cytnx.Network()
    anet.FromString(["L: -2,-1,-3",\
                        "A: -1,-4,1",\
                        "M: -2,0,-4,-5",\
                        "A_Conj: -3,-5,2",\
                        "TOUT: 0,1,2"])
    # or you can do: anet = cytnx.Network("L_AMAH.net")
    anet.PutUniTensors(["L","A","A_Conj","M"],[LR[p],A[p],A[p].Conj(),M])
    LR[p+1] = anet.Launch()

    # Recover the original MPS labels
    A[p].relabels_(lbls[p])
    A[p+1].relabels_(lbls[p+1])

_,A[-1] = cytnx.linalg.Gesvd(A[-1],is_U=True,is_vT=False) ## last one.
A[-1].relabels_(lbls[-1]) # Recover the original MPS labels
# Out:
# -------- start of print ---------
# Tensor name:
# is_diag    : False
# contiguous : True
#
# Total elem: 4
# type  : Double (Float64)
# cytnx device: CPU
# Shape : (2,2,1)
# [[[4.44611e-01 ]
#   [-6.82189e-01 ]]
#  [[-4.31262e-01 ]
#   [3.88525e-01 ]]]

# %% [markdown]
# ### 3.2 Define effective Hamiltonian and $\hat{H}|\psi\rangle$ operation

# %% [markdown]
# <img src="https://github.com/Cytnx-dev/Cytnx_colab_tutorial/blob/main/figures/heff.png?raw=1" alt="drawing" width="600"/>

# %%
# An effective Hamiltonian must:
# 1. Inherit <cytnx.LinOp> class
# 2. Has a function <matvec> that implements H|psi> operation

class Hxx(cytnx.LinOp):

    def __init__(self, anet, psidim):
        cytnx.LinOp.__init__(self,"mv", psidim, cytnx.Type.Double, cytnx.Device.cpu)
        self.anet = anet

    def matvec(self, v):
        lbl = v.labels()
        self.anet.PutUniTensor("psi",v)
        out = self.anet.Launch()
        out.relabels_(lbl)
        return out

# %% [markdown]
# ## 4. Find the ground state by DMRG

# %% [markdown]
# ### 4.1 DMRG algorithm

# %% [markdown]
# <img src="https://github.com/Cytnx-dev/Cytnx_colab_tutorial/blob/main/figures/dmrg_sweep.png?raw=1" alt="drawing" width="600"/>
# <img src="https://github.com/Cytnx-dev/Cytnx_colab_tutorial/blob/main/figures/twositecontract.png?raw=1" alt="drawing" width="650"/>

# %%
def dmrg_XXmodel_dense(Nsites, chi, numsweeps, maxit):
    class Hxx(cytnx.LinOp):

        def __init__(self, anet, psidim):
            cytnx.LinOp.__init__(self,"mv", psidim, cytnx.Type.Double, cytnx.Device.cpu)
            self.anet = anet

        def matvec(self, v):
            lbl = v.labels()
            self.anet.PutUniTensor("psi",v)
            out = self.anet.Launch()
            out.relabels_(lbl)
            return out

    def optimize_psi(psi, functArgs, maxit=2, krydim=4):

        L,M1,M2,R = functArgs
        anet = cytnx.Network()
        anet.FromString(["psi: -1,-2,-3,-4",\
                        "L: -5,-1,0",\
                        "R: -7,-4,3",\
                        "M1: -5,-6,-2,1",\
                        "M2: -6,-7,-3,2",\
                        "TOUT: 0,1;2,3"])
        # or you can do : anet = cytnx.Network("projector.net")
        anet.PutUniTensors(["L","M1","M2","R"],[L,M1,M2,R])

        H = Hxx(anet, psi.shape()[0]*psi.shape()[1]*psi.shape()[2]*psi.shape()[3])
        energy, psivec = cytnx.linalg.Lanczos(Hop = H, method = "Gnd", Maxiter = 4, CvgCrit = 9999999999, Tin = psi)

        return psivec, energy[0].item()
    Ekeep = []
    for k in range(1, numsweeps+1):

        for p in range(Nsites-2,-1,-1):
            dim_l = A[p].shape()[0]
            dim_r = A[p+1].shape()[2]
            new_dim = min(dim_l*d,dim_r*d,chi)

            psi = cytnx.Contract(A[p],A[p+1]) # contract
            psi, Entemp = optimize_psi(psi, (LR[p],M,M,LR[p+2]), maxit)
            Ekeep.append(Entemp)

            psi.set_rowrank_(2) # maintain rowrank to perform the svd
            s,A[p],A[p+1] = cytnx.linalg.Svd_truncate(psi,new_dim)
            A[p+1].relabels_(lbls[p+1]); # set the label back to be consistent

            s = s/s.Norm().item() # normalize s

            A[p] = cytnx.Contract(A[p],s) # absorb s into next neighbor
            A[p].relabels_(lbls[p]); # set the label back to be consistent

            # update LR from right to left:
            anet = cytnx.Network()
            anet.FromString(["R: -2,-1,-3",\
                            "B: 1,-4,-1",\
                            "M: 0,-2,-4,-5",\
                            "B_Conj: 2,-5,-3",\
                            "TOUT: 0;1,2"])
            # or you can do: anet = cytnx.Network("R_AMAH.net")
            anet.PutUniTensors(["R","B","M","B_Conj"],[LR[p+2],A[p+1],M,A[p+1].Conj()])
            LR[p+1] = anet.Launch()

            print('Sweep[r->l]: %d/%d, Loc: %d,Energy: %f' % (k, numsweeps, p, Ekeep[-1]))

        A[0].set_rowrank_(1)
        _,A[0] = cytnx.linalg.Gesvd(A[0],is_U=False, is_vT=True)
        A[0].relabels_(lbls[0]); #set the label back to be consistent

        for p in range(Nsites-1):
            dim_l = A[p].shape()[0]
            dim_r = A[p+1].shape()[2]
            new_dim = min(dim_l*d,dim_r*d,chi)

            psi = cytnx.Contract(A[p],A[p+1]) ## contract
            psi, Entemp = optimize_psi(psi, (LR[p],M,M,LR[p+2]), maxit)
            Ekeep.append(Entemp)

            psi.set_rowrank_(2) # maintain rowrank to perform the svd
            s,A[p],A[p+1] = cytnx.linalg.Svd_truncate(psi,new_dim)
            A[p].relabels_(lbls[p]); #set the label back to be consistent

            s = s/s.Norm().item() # normalize s

            A[p+1] = cytnx.Contract(s,A[p+1]) ## absorb s into next neighbor.
            A[p+1].relabels_(lbls[p+1]); #set the label back to be consistent

            # update LR from left to right:
            anet = cytnx.Network()
            anet.FromString(["L: -2,-1,-3",\
                            "A: -1,-4,1",\
                            "M: -2,0,-4,-5",\
                            "A_Conj: -3,-5,2",\
                            "TOUT: 0,1,2"])
            # or you can do: anet = cytnx.Network("L_AMAH.net")

            anet.PutUniTensors(["L","A","A_Conj","M"],[LR[p],A[p],A[p].Conj(),M])
            LR[p+1] = anet.Launch()

            print('Sweep[l->r]: %d/%d, Loc: %d,Energy: %f' % (k, numsweeps, p, Ekeep[-1]))

        A[-1].set_rowrank_(2)
        _,A[-1] = cytnx.linalg.Gesvd(A[-1],is_U=True,is_vT=False) ## last one.
        A[-1].relabels_(lbls[-1]); #set the label back to be consistent
    return Ekeep

# %%
numsweeps = 6 # number of DMRG sweeps
maxit = 2 # iterations of Lanczos method

Es = dmrg_XXmodel_dense(Nsites, chi, numsweeps, maxit)

#### Compare with exact results (computed from free fermions)
from numpy import linalg as LA
H = np.diag(np.ones(Nsites-1),k=1) + np.diag(np.ones(Nsites-1),k=-1)
D = LA.eigvalsh(H)
EnExact = 2*sum(D[D < 0])

print("Energy error = ", np.abs(Es[-1]-EnExact))
# Out:
# Sweep[r->l]: 1/6, Loc: 18,Energy: -1.994215
# Sweep[r->l]: 1/6, Loc: 17,Energy: -3.544270
# Sweep[r->l]: 1/6, Loc: 16,Energy: -5.038758
# Sweep[r->l]: 1/6, Loc: 15,Energy: -6.533731
# Sweep[r->l]: 1/6, Loc: 14,Energy: -7.723275
# Sweep[r->l]: 1/6, Loc: 13,Energy: -8.828938
# Sweep[r->l]: 1/6, Loc: 12,Energy: -9.841415
# Sweep[r->l]: 1/6, Loc: 11,Energy: -10.833828
# Sweep[r->l]: 1/6, Loc: 10,Energy: -11.958287
# Sweep[r->l]: 1/6, Loc: 9,Energy: -13.152816
# Sweep[r->l]: 1/6, Loc: 8,Energy: -14.426413
# Sweep[r->l]: 1/6, Loc: 7,Energy: -15.766615
# Sweep[r->l]: 1/6, Loc: 6,Energy: -17.101372
# Sweep[r->l]: 1/6, Loc: 5,Energy: -18.397338
# Sweep[r->l]: 1/6, Loc: 4,Energy: -19.465837
# Sweep[r->l]: 1/6, Loc: 3,Energy: -20.309658
# Sweep[r->l]: 1/6, Loc: 2,Energy: -20.849390
# Sweep[r->l]: 1/6, Loc: 1,Energy: -21.085001
# Sweep[r->l]: 1/6, Loc: 0,Energy: -21.506409
# Sweep[l->r]: 1/6, Loc: 0,Energy: -21.573696
# Sweep[l->r]: 1/6, Loc: 1,Energy: -21.687337
# Sweep[l->r]: 1/6, Loc: 2,Energy: -22.083227
# Sweep[l->r]: 1/6, Loc: 3,Energy: -22.464763
# Sweep[l->r]: 1/6, Loc: 4,Energy: -22.793512
# Sweep[l->r]: 1/6, Loc: 5,Energy: -23.050949
# Sweep[l->r]: 1/6, Loc: 6,Energy: -23.294904
# Sweep[l->r]: 1/6, Loc: 7,Energy: -23.487244
# Sweep[l->r]: 1/6, Loc: 8,Energy: -23.639293
# Sweep[l->r]: 1/6, Loc: 9,Energy: -23.760722
# Sweep[l->r]: 1/6, Loc: 10,Energy: -23.855113
# Sweep[l->r]: 1/6, Loc: 11,Energy: -23.928949
# Sweep[l->r]: 1/6, Loc: 12,Energy: -23.981332
# Sweep[l->r]: 1/6, Loc: 13,Energy: -24.018396
# Sweep[l->r]: 1/6, Loc: 14,Energy: -24.043993
# Sweep[l->r]: 1/6, Loc: 15,Energy: -24.061347
# Sweep[l->r]: 1/6, Loc: 16,Energy: -24.070482
# Sweep[l->r]: 1/6, Loc: 17,Energy: -24.076345
# Sweep[l->r]: 1/6, Loc: 18,Energy: -24.119530
# Sweep[r->l]: 2/6, Loc: 18,Energy: -24.131959
# Sweep[r->l]: 2/6, Loc: 17,Energy: -24.140077
# Sweep[r->l]: 2/6, Loc: 16,Energy: -24.148648
# Sweep[r->l]: 2/6, Loc: 15,Energy: -24.162835
# Sweep[r->l]: 2/6, Loc: 14,Energy: -24.178505
# Sweep[r->l]: 2/6, Loc: 13,Energy: -24.196492
# Sweep[r->l]: 2/6, Loc: 12,Energy: -24.216137
# Sweep[r->l]: 2/6, Loc: 11,Energy: -24.245714
# Sweep[r->l]: 2/6, Loc: 10,Energy: -24.272484
# Sweep[r->l]: 2/6, Loc: 9,Energy: -24.301713
# Sweep[r->l]: 2/6, Loc: 8,Energy: -24.327168
# Sweep[r->l]: 2/6, Loc: 7,Energy: -24.354880
# Sweep[r->l]: 2/6, Loc: 6,Energy: -24.377868
# Sweep[r->l]: 2/6, Loc: 5,Energy: -24.397361
# Sweep[r->l]: 2/6, Loc: 4,Energy: -24.413708
# Sweep[r->l]: 2/6, Loc: 3,Energy: -24.427272
# Sweep[r->l]: 2/6, Loc: 2,Energy: -24.437809
# Sweep[r->l]: 2/6, Loc: 1,Energy: -24.450559
# Sweep[r->l]: 2/6, Loc: 0,Energy: -24.493841
# Sweep[l->r]: 2/6, Loc: 0,Energy: -24.510613
# Sweep[l->r]: 2/6, Loc: 1,Energy: -24.522077
# Sweep[l->r]: 2/6, Loc: 2,Energy: -24.529479
# Sweep[l->r]: 2/6, Loc: 3,Energy: -24.536983
# Sweep[l->r]: 2/6, Loc: 4,Energy: -24.544329
# Sweep[l->r]: 2/6, Loc: 5,Energy: -24.551114
# Sweep[l->r]: 2/6, Loc: 6,Energy: -24.557431
# Sweep[l->r]: 2/6, Loc: 7,Energy: -24.563209
# Sweep[l->r]: 2/6, Loc: 8,Energy: -24.568580
# Sweep[l->r]: 2/6, Loc: 9,Energy: -24.573483
# Sweep[l->r]: 2/6, Loc: 10,Energy: -24.578017
# Sweep[l->r]: 2/6, Loc: 11,Energy: -24.582134
# Sweep[l->r]: 2/6, Loc: 12,Energy: -24.585860
# Sweep[l->r]: 2/6, Loc: 13,Energy: -24.589287
# Sweep[l->r]: 2/6, Loc: 14,Energy: -24.592322
# Sweep[l->r]: 2/6, Loc: 15,Energy: -24.595009
# Sweep[l->r]: 2/6, Loc: 16,Energy: -24.596916
# Sweep[l->r]: 2/6, Loc: 17,Energy: -24.599266
# Sweep[l->r]: 2/6, Loc: 18,Energy: -24.609346
# Sweep[r->l]: 3/6, Loc: 18,Energy: -24.610930
# Sweep[r->l]: 3/6, Loc: 17,Energy: -24.614505
# Sweep[r->l]: 3/6, Loc: 16,Energy: -24.617029
# Sweep[r->l]: 3/6, Loc: 15,Energy: -24.620072
# Sweep[r->l]: 3/6, Loc: 14,Energy: -24.623114
# Sweep[r->l]: 3/6, Loc: 13,Energy: -24.626145
# Sweep[r->l]: 3/6, Loc: 12,Energy: -24.629068
# Sweep[r->l]: 3/6, Loc: 11,Energy: -24.632131
# Sweep[r->l]: 3/6, Loc: 10,Energy: -24.635188
# Sweep[r->l]: 3/6, Loc: 9,Energy: -24.638320
# Sweep[r->l]: 3/6, Loc: 8,Energy: -24.641316
# Sweep[r->l]: 3/6, Loc: 7,Energy: -24.644204
# Sweep[r->l]: 3/6, Loc: 6,Energy: -24.646957
# Sweep[r->l]: 3/6, Loc: 5,Energy: -24.649599
# Sweep[r->l]: 3/6, Loc: 4,Energy: -24.652118
# Sweep[r->l]: 3/6, Loc: 3,Energy: -24.654521
# Sweep[r->l]: 3/6, Loc: 2,Energy: -24.656806
# Sweep[r->l]: 3/6, Loc: 1,Energy: -24.663398
# Sweep[r->l]: 3/6, Loc: 0,Energy: -24.672307
# Sweep[l->r]: 3/6, Loc: 0,Energy: -24.676371
# Sweep[l->r]: 3/6, Loc: 1,Energy: -24.682357
# Sweep[l->r]: 3/6, Loc: 2,Energy: -24.684457
# Sweep[l->r]: 3/6, Loc: 3,Energy: -24.686445
# Sweep[l->r]: 3/6, Loc: 4,Energy: -24.688337
# Sweep[l->r]: 3/6, Loc: 5,Energy: -24.690143
# Sweep[l->r]: 3/6, Loc: 6,Energy: -24.691875
# Sweep[l->r]: 3/6, Loc: 7,Energy: -24.693544
# Sweep[l->r]: 3/6, Loc: 8,Energy: -24.695157
# Sweep[l->r]: 3/6, Loc: 9,Energy: -24.696724
# Sweep[l->r]: 3/6, Loc: 10,Energy: -24.698249
# Sweep[l->r]: 3/6, Loc: 11,Energy: -24.699736
# Sweep[l->r]: 3/6, Loc: 12,Energy: -24.701171
# Sweep[l->r]: 3/6, Loc: 13,Energy: -24.702553
# Sweep[l->r]: 3/6, Loc: 14,Energy: -24.703886
# Sweep[l->r]: 3/6, Loc: 15,Energy: -24.705164
# Sweep[l->r]: 3/6, Loc: 16,Energy: -24.706274
# Sweep[l->r]: 3/6, Loc: 17,Energy: -24.707671
# Sweep[l->r]: 3/6, Loc: 18,Energy: -24.711677
# Sweep[r->l]: 4/6, Loc: 18,Energy: -24.712212
# Sweep[r->l]: 4/6, Loc: 17,Energy: -24.714164
# Sweep[r->l]: 4/6, Loc: 16,Energy: -24.715532
# Sweep[r->l]: 4/6, Loc: 15,Energy: -24.716959
# Sweep[r->l]: 4/6, Loc: 14,Energy: -24.718317
# Sweep[r->l]: 4/6, Loc: 13,Energy: -24.719607
# Sweep[r->l]: 4/6, Loc: 12,Energy: -24.720846
# Sweep[r->l]: 4/6, Loc: 11,Energy: -24.722036
# Sweep[r->l]: 4/6, Loc: 10,Energy: -24.723179
# Sweep[r->l]: 4/6, Loc: 9,Energy: -24.724282
# Sweep[r->l]: 4/6, Loc: 8,Energy: -24.725344
# Sweep[r->l]: 4/6, Loc: 7,Energy: -24.726377
# Sweep[r->l]: 4/6, Loc: 6,Energy: -24.727371
# Sweep[r->l]: 4/6, Loc: 5,Energy: -24.728325
# Sweep[r->l]: 4/6, Loc: 4,Energy: -24.729232
# Sweep[r->l]: 4/6, Loc: 3,Energy: -24.730089
# Sweep[r->l]: 4/6, Loc: 2,Energy: -24.730903
# Sweep[r->l]: 4/6, Loc: 1,Energy: -24.735058
# Sweep[r->l]: 4/6, Loc: 0,Energy: -24.737381
# Sweep[l->r]: 4/6, Loc: 0,Energy: -24.738419
# Sweep[l->r]: 4/6, Loc: 1,Energy: -24.741305
# Sweep[l->r]: 4/6, Loc: 2,Energy: -24.742017
# Sweep[l->r]: 4/6, Loc: 3,Energy: -24.742685
# Sweep[l->r]: 4/6, Loc: 4,Energy: -24.743327
# Sweep[l->r]: 4/6, Loc: 5,Energy: -24.743939
# Sweep[l->r]: 4/6, Loc: 6,Energy: -24.744521
# Sweep[l->r]: 4/6, Loc: 7,Energy: -24.745082
# Sweep[l->r]: 4/6, Loc: 8,Energy: -24.745617
# Sweep[l->r]: 4/6, Loc: 9,Energy: -24.746130
# Sweep[l->r]: 4/6, Loc: 10,Energy: -24.746621
# Sweep[l->r]: 4/6, Loc: 11,Energy: -24.747098
# Sweep[l->r]: 4/6, Loc: 12,Energy: -24.747555
# Sweep[l->r]: 4/6, Loc: 13,Energy: -24.747989
# Sweep[l->r]: 4/6, Loc: 14,Energy: -24.748402
# Sweep[l->r]: 4/6, Loc: 15,Energy: -24.748794
# Sweep[l->r]: 4/6, Loc: 16,Energy: -24.749155
# Sweep[l->r]: 4/6, Loc: 17,Energy: -24.749965
# Sweep[l->r]: 4/6, Loc: 18,Energy: -24.751306
# Sweep[r->l]: 5/6, Loc: 18,Energy: -24.751500
# Sweep[r->l]: 5/6, Loc: 17,Energy: -24.752364
# Sweep[r->l]: 5/6, Loc: 16,Energy: -24.752743
# Sweep[r->l]: 5/6, Loc: 15,Energy: -24.753114
# Sweep[r->l]: 5/6, Loc: 14,Energy: -24.753461
# Sweep[r->l]: 5/6, Loc: 13,Energy: -24.753790
# Sweep[r->l]: 5/6, Loc: 12,Energy: -24.754100
# Sweep[r->l]: 5/6, Loc: 11,Energy: -24.754394
# Sweep[r->l]: 5/6, Loc: 10,Energy: -24.754671
# Sweep[r->l]: 5/6, Loc: 9,Energy: -24.754935
# Sweep[r->l]: 5/6, Loc: 8,Energy: -24.755186
# Sweep[r->l]: 5/6, Loc: 7,Energy: -24.755427
# Sweep[r->l]: 5/6, Loc: 6,Energy: -24.755656
# Sweep[r->l]: 5/6, Loc: 5,Energy: -24.755874
# Sweep[r->l]: 5/6, Loc: 4,Energy: -24.756078
# Sweep[r->l]: 5/6, Loc: 3,Energy: -24.756268
# Sweep[r->l]: 5/6, Loc: 2,Energy: -24.756448
# Sweep[r->l]: 5/6, Loc: 1,Energy: -24.758474
# Sweep[r->l]: 5/6, Loc: 0,Energy: -24.758854
# Sweep[l->r]: 5/6, Loc: 0,Energy: -24.758991
# Sweep[l->r]: 5/6, Loc: 1,Energy: -24.759547
# Sweep[l->r]: 5/6, Loc: 2,Energy: -24.759764
# Sweep[l->r]: 5/6, Loc: 3,Energy: -24.759947
# Sweep[l->r]: 5/6, Loc: 4,Energy: -24.760110
# Sweep[l->r]: 5/6, Loc: 5,Energy: -24.760255
# Sweep[l->r]: 5/6, Loc: 6,Energy: -24.760385
# Sweep[l->r]: 5/6, Loc: 7,Energy: -24.760504
# Sweep[l->r]: 5/6, Loc: 8,Energy: -24.760614
# Sweep[l->r]: 5/6, Loc: 9,Energy: -24.760711
# Sweep[l->r]: 5/6, Loc: 10,Energy: -24.760797
# Sweep[l->r]: 5/6, Loc: 11,Energy: -24.760878
# Sweep[l->r]: 5/6, Loc: 12,Energy: -24.760956
# Sweep[l->r]: 5/6, Loc: 13,Energy: -24.761027
# Sweep[l->r]: 5/6, Loc: 14,Energy: -24.761092
# Sweep[l->r]: 5/6, Loc: 15,Energy: -24.761150
# Sweep[l->r]: 5/6, Loc: 16,Energy: -24.761206
# Sweep[l->r]: 5/6, Loc: 17,Energy: -24.761567
# Sweep[l->r]: 5/6, Loc: 18,Energy: -24.761762
# Sweep[r->l]: 6/6, Loc: 18,Energy: -24.761800
# Sweep[r->l]: 6/6, Loc: 17,Energy: -24.761969
# Sweep[r->l]: 6/6, Loc: 16,Energy: -24.762021
# Sweep[r->l]: 6/6, Loc: 15,Energy: -24.762066
# Sweep[r->l]: 6/6, Loc: 14,Energy: -24.762108
# Sweep[r->l]: 6/6, Loc: 13,Energy: -24.762147
# Sweep[r->l]: 6/6, Loc: 12,Energy: -24.762184
# Sweep[r->l]: 6/6, Loc: 11,Energy: -24.762217
# Sweep[r->l]: 6/6, Loc: 10,Energy: -24.762248
# Sweep[r->l]: 6/6, Loc: 9,Energy: -24.762281
# Sweep[r->l]: 6/6, Loc: 8,Energy: -24.762311
# Sweep[r->l]: 6/6, Loc: 7,Energy: -24.762339
# Sweep[r->l]: 6/6, Loc: 6,Energy: -24.762365
# Sweep[r->l]: 6/6, Loc: 5,Energy: -24.762388
# Sweep[r->l]: 6/6, Loc: 4,Energy: -24.762408
# Sweep[r->l]: 6/6, Loc: 3,Energy: -24.762426
# Sweep[r->l]: 6/6, Loc: 2,Energy: -24.762442
# Sweep[r->l]: 6/6, Loc: 1,Energy: -24.762631
# Sweep[r->l]: 6/6, Loc: 0,Energy: -24.762653
# Sweep[l->r]: 6/6, Loc: 0,Energy: -24.762660
# Sweep[l->r]: 6/6, Loc: 1,Energy: -24.762669
# Sweep[l->r]: 6/6, Loc: 2,Energy: -24.762700
# Sweep[l->r]: 6/6, Loc: 3,Energy: -24.762724
# Sweep[l->r]: 6/6, Loc: 4,Energy: -24.762746
# Sweep[l->r]: 6/6, Loc: 5,Energy: -24.762764
# Sweep[l->r]: 6/6, Loc: 6,Energy: -24.762780
# Sweep[l->r]: 6/6, Loc: 7,Energy: -24.762794
# Sweep[l->r]: 6/6, Loc: 8,Energy: -24.762806
# Sweep[l->r]: 6/6, Loc: 9,Energy: -24.762817
# Sweep[l->r]: 6/6, Loc: 10,Energy: -24.762826
# Sweep[l->r]: 6/6, Loc: 11,Energy: -24.762833
# Sweep[l->r]: 6/6, Loc: 12,Energy: -24.762841
# Sweep[l->r]: 6/6, Loc: 13,Energy: -24.762847
# Sweep[l->r]: 6/6, Loc: 14,Energy: -24.762853
# Sweep[l->r]: 6/6, Loc: 15,Energy: -24.762857
# Sweep[l->r]: 6/6, Loc: 16,Energy: -24.762861
# Sweep[l->r]: 6/6, Loc: 17,Energy: -24.762903
# Sweep[l->r]: 6/6, Loc: 18,Energy: -24.762912
# Energy error =  6.764065524222929e-05

# %%
plt.plot(Es, marker = 'o')
plt.xlabel('Step')
plt.ylabel('Energy')
plt.show()

# %% [markdown]
# ## Try it
# Find the ground state energy of the **antiferromagnet Heisenberg model** given by the Hamiltonian:
#
# $$\hat{H} = \sum_{i=1}^{N-1} \hat{S}^x_i\hat{S}^x_{i+1} + \hat{S}^y_i\hat{S}^y_{i+1} + \hat{S}^z_i\hat{S}^z_{i+1}$$
#
# Please try several values of $N$ and **extraplolated** to $N \to \infty$ and compare to the exact value at **thermaldynamic limit**:
# $$1/4 - log(2) \approx -0.4431$$

# %% [markdown]
# ## DMRG whole implementation

# %%
import sys,os
import numpy as np
import cytnx

"""
Reference: https://www.tensors.net
Author: Yu-Hsueh Chen, Kai-Hsin Wu, Ke Hsu (j9263178)
"""

def dmrg_XXmodel_dense(Nsites, chi, numsweeps, maxit):
    class Hxx(cytnx.LinOp):

        def __init__(self, anet, psidim):
            cytnx.LinOp.__init__(self,"mv", psidim, cytnx.Type.Double, cytnx.Device.cpu)
            self.anet = anet

        def matvec(self, v):
            lbl = v.labels()
            self.anet.PutUniTensor("psi",v)
            out = self.anet.Launch()
            out.relabels_(lbl)
            return out

    def optimize_psi(psi, functArgs, maxit=2, krydim=4):

        L,M1,M2,R = functArgs
        anet = cytnx.Network()
        anet.FromString(["psi: -1,-2,-3,-4",\
                        "L: -5,-1,0",\
                        "R: -7,-4,3",\
                        "M1: -5,-6,-2,1",\
                        "M2: -6,-7,-3,2",\
                        "TOUT: 0,1;2,3"])
        # or you can do : anet = cytnx.Network("projector.net")
        anet.PutUniTensors(["L","M1","M2","R"],[L,M1,M2,R])

        H = Hxx(anet, psi.shape()[0]*psi.shape()[1]*psi.shape()[2]*psi.shape()[3])
        energy, psivec = cytnx.linalg.Lanczos(Hop = H, method = "Gnd", Maxiter = 4, CvgCrit = 9999999999, Tin = psi)

        return psivec, energy[0].item()

    d = 2 #physical dimension
    s = 0.5 #spin-half

    sx = cytnx.physics.spin(0.5,'x')
    sy = cytnx.physics.spin(0.5,'y')
    sp = sx+1j*sy
    sm = sx-1j*sy

    eye = cytnx.eye(d)
    M = cytnx.zeros([4, 4, d, d])
    M[0,0] = M[3,3] = eye
    M[0,1] = M[2,3] = 2**0.5*sp.real()
    M[0,2] = M[1,3] = 2**0.5*sm.real()
    M = cytnx.UniTensor(M,0)

    L0 = cytnx.UniTensor(cytnx.zeros([4,1,1]), rowrank = 0) #Left boundary
    R0 = cytnx.UniTensor(cytnx.zeros([4,1,1]), rowrank = 0) #Right boundary
    L0[0,0,0] = 1.; R0[3,0,0] = 1.

    lbls = [] # List for storing the MPS labels
    A = [None for i in range(Nsites)]
    A[0] = cytnx.UniTensor(cytnx.random.normal([1, d, min(chi, d)], 0., 1.), rowrank = 2)
    A[0].relabels_(["0","1","2"])
    lbls.append(["0","1","2"]) # store the labels for later convinience.

    for k in range(1,Nsites):
        dim1 = A[k-1].shape()[2]; dim2 = d
        dim3 = min(min(chi, A[k-1].shape()[2] * d), d ** (Nsites - k - 1))
        A[k] = cytnx.UniTensor(cytnx.random.normal([dim1, dim2, dim3],0.,1.), rowrank = 2)

        lbl = [str(2*k),str(2*k+1),str(2*k+2)]
        A[k].relabels_(lbl)
        lbls.append(lbl) # store the labels for later convinience.

    LR = [None for i in range(Nsites+1)]
    LR[0]  = L0
    LR[-1] = R0


    for p in range(Nsites - 1):

        ## Changing to canonical form site by site:
        s, A[p] ,vt = cytnx.linalg.Gesvd(A[p])
        A[p+1] = cytnx.Contract(cytnx.Contract(s,vt),A[p+1])

        ## Calculate enviroments:
        anet = cytnx.Network()
        anet.FromString(["L: -2,-1,-3",\
                        "A: -1,-4,1",\
                        "M: -2,0,-4,-5",\
                        "A_Conj: -3,-5,2",\
                        "TOUT: 0,1,2"])
        # or you can do: anet = cytnx.Network("L_AMAH.net")
        anet.PutUniTensors(["L","A","A_Conj","M"],[LR[p],A[p],A[p].Conj(),M])
        LR[p+1] = anet.Launch()

        # Recover the original MPS labels
        A[p].relabels_(lbls[p])
        A[p+1].relabels_(lbls[p+1])

    _,A[-1] = cytnx.linalg.Gesvd(A[-1],is_U=True,is_vT=False) ## last one.
    A[-1].relabels_(lbls[-1]) # Recover the original MPS labels

    Ekeep = []
    for k in range(1, numsweeps+1):

        for p in range(Nsites-2,-1,-1):
            dim_l = A[p].shape()[0]
            dim_r = A[p+1].shape()[2]
            new_dim = min(dim_l*d,dim_r*d,chi)

            psi = cytnx.Contract(A[p],A[p+1]) # contract
            psi, Entemp = optimize_psi(psi, (LR[p],M,M,LR[p+2]), maxit)
            Ekeep.append(Entemp)

            psi.set_rowrank_(2) # maintain rowrank to perform the svd
            s,A[p],A[p+1] = cytnx.linalg.Svd_truncate(psi,new_dim)
            A[p+1].relabels_(lbls[p+1]); # set the label back to be consistent

            s = s/s.Norm().item() # normalize s

            A[p] = cytnx.Contract(A[p],s) # absorb s into next neighbor
            A[p].relabels_(lbls[p]); # set the label back to be consistent

            # update LR from right to left:
            anet = cytnx.Network()
            anet.FromString(["R: -2,-1,-3",\
                            "B: 1,-4,-1",\
                            "M: 0,-2,-4,-5",\
                            "B_Conj: 2,-5,-3",\
                            "TOUT: 0;1,2"])
            # or you can do: anet = cytnx.Network("R_AMAH.net")
            anet.PutUniTensors(["R","B","M","B_Conj"],[LR[p+2],A[p+1],M,A[p+1].Conj()])
            LR[p+1] = anet.Launch()

            print('Sweep[r->l]: %d/%d, Loc: %d,Energy: %f' % (k, numsweeps, p, Ekeep[-1]))

        A[0].set_rowrank_(1)
        _,A[0] = cytnx.linalg.Gesvd(A[0],is_U=False, is_vT=True)
        A[0].relabels_(lbls[0]); #set the label back to be consistent

        for p in range(Nsites-1):
            dim_l = A[p].shape()[0]
            dim_r = A[p+1].shape()[2]
            new_dim = min(dim_l*d,dim_r*d,chi)

            psi = cytnx.Contract(A[p],A[p+1]) ## contract
            psi, Entemp = optimize_psi(psi, (LR[p],M,M,LR[p+2]), maxit)
            Ekeep.append(Entemp)

            psi.set_rowrank_(2) # maintain rowrank to perform the svd
            s,A[p],A[p+1] = cytnx.linalg.Svd_truncate(psi,new_dim)
            A[p].relabels_(lbls[p]); #set the label back to be consistent

            s = s/s.Norm().item() # normalize s

            A[p+1] = cytnx.Contract(s,A[p+1]) ## absorb s into next neighbor.
            A[p+1].relabels_(lbls[p+1]); #set the label back to be consistent

            # update LR from left to right:
            anet = cytnx.Network()
            anet.FromString(["L: -2,-1,-3",\
                            "A: -1,-4,1",\
                            "M: -2,0,-4,-5",\
                            "A_Conj: -3,-5,2",\
                            "TOUT: 0,1,2"])
            # or you can do: anet = cytnx.Network("L_AMAH.net")

            anet.PutUniTensors(["L","A","A_Conj","M"],[LR[p],A[p],A[p].Conj(),M])
            LR[p+1] = anet.Launch()

            print('Sweep[l->r]: %d/%d, Loc: %d,Energy: %f' % (k, numsweeps, p, Ekeep[-1]))

        A[-1].set_rowrank_(2)
        _,A[-1] = cytnx.linalg.Gesvd(A[-1],is_U=True,is_vT=False) ## last one.
        A[-1].relabels_(lbls[-1]); #set the label back to be consistent
    return Ekeep

if __name__ == '__main__':


    Nsites = 20 # Number of sites
    chi = 32 # MPS bond dimension
    numsweeps = 6 # number of DMRG sweeps
    maxit = 2 # iterations of Lanczos method

    Es = dmrg_XXmodel_dense(Nsites, chi, numsweeps, maxit)

    #### Compare with exact results (computed from free fermions)
    from numpy import linalg as LA
    # import matplotlib.pyplot as plt
    H = np.diag(np.ones(Nsites-1),k=1) + np.diag(np.ones(Nsites-1),k=-1)
    D = LA.eigvalsh(H)
    EnExact = 2*sum(D[D < 0])

    print("Energy error = ", np.abs(Es[-1]-EnExact))
# Out:
# Sweep[r->l]: 1/6, Loc: 18,Energy: -1.780585
# Sweep[r->l]: 1/6, Loc: 17,Energy: -3.075102
# Sweep[r->l]: 1/6, Loc: 16,Energy: -4.201384
# Sweep[r->l]: 1/6, Loc: 15,Energy: -5.542078
# Sweep[r->l]: 1/6, Loc: 14,Energy: -6.623535
# Sweep[r->l]: 1/6, Loc: 13,Energy: -7.623668
# Sweep[r->l]: 1/6, Loc: 12,Energy: -8.576859
# Sweep[r->l]: 1/6, Loc: 11,Energy: -9.603825
# Sweep[r->l]: 1/6, Loc: 10,Energy: -10.632519
# Sweep[r->l]: 1/6, Loc: 9,Energy: -11.773484
# Sweep[r->l]: 1/6, Loc: 8,Energy: -13.087680
# Sweep[r->l]: 1/6, Loc: 7,Energy: -14.381698
# Sweep[r->l]: 1/6, Loc: 6,Energy: -15.790255
# Sweep[r->l]: 1/6, Loc: 5,Energy: -17.104504
# Sweep[r->l]: 1/6, Loc: 4,Energy: -18.097879
# Sweep[r->l]: 1/6, Loc: 3,Energy: -18.874033
# Sweep[r->l]: 1/6, Loc: 2,Energy: -19.392338
# Sweep[r->l]: 1/6, Loc: 1,Energy: -19.785292
# Sweep[r->l]: 1/6, Loc: 0,Energy: -20.362552
# Sweep[l->r]: 1/6, Loc: 0,Energy: -20.681802
# Sweep[l->r]: 1/6, Loc: 1,Energy: -21.145507
# Sweep[l->r]: 1/6, Loc: 2,Energy: -21.458575
# Sweep[l->r]: 1/6, Loc: 3,Energy: -21.837204
# Sweep[l->r]: 1/6, Loc: 4,Energy: -22.140770
# Sweep[l->r]: 1/6, Loc: 5,Energy: -22.412833
# Sweep[l->r]: 1/6, Loc: 6,Energy: -22.643387
# Sweep[l->r]: 1/6, Loc: 7,Energy: -22.850281
# Sweep[l->r]: 1/6, Loc: 8,Energy: -23.038246
# Sweep[l->r]: 1/6, Loc: 9,Energy: -23.193933
# Sweep[l->r]: 1/6, Loc: 10,Energy: -23.316896
# Sweep[l->r]: 1/6, Loc: 11,Energy: -23.421385
# Sweep[l->r]: 1/6, Loc: 12,Energy: -23.505058
# Sweep[l->r]: 1/6, Loc: 13,Energy: -23.571437
# Sweep[l->r]: 1/6, Loc: 14,Energy: -23.625252
# Sweep[l->r]: 1/6, Loc: 15,Energy: -23.670253
# Sweep[l->r]: 1/6, Loc: 16,Energy: -23.696876
# Sweep[l->r]: 1/6, Loc: 17,Energy: -23.713330
# Sweep[l->r]: 1/6, Loc: 18,Energy: -23.748623
# Sweep[r->l]: 2/6, Loc: 18,Energy: -23.770614
# Sweep[r->l]: 2/6, Loc: 17,Energy: -23.787823
# Sweep[r->l]: 2/6, Loc: 16,Energy: -23.809651
# Sweep[r->l]: 2/6, Loc: 15,Energy: -23.842626
# Sweep[r->l]: 2/6, Loc: 14,Energy: -23.873276
# Sweep[r->l]: 2/6, Loc: 13,Energy: -23.903072
# Sweep[r->l]: 2/6, Loc: 12,Energy: -23.933182
# Sweep[r->l]: 2/6, Loc: 11,Energy: -23.960411
# Sweep[r->l]: 2/6, Loc: 10,Energy: -23.985848
# Sweep[r->l]: 2/6, Loc: 9,Energy: -24.016135
# Sweep[r->l]: 2/6, Loc: 8,Energy: -24.046017
# Sweep[r->l]: 2/6, Loc: 7,Energy: -24.076096
# Sweep[r->l]: 2/6, Loc: 6,Energy: -24.106107
# Sweep[r->l]: 2/6, Loc: 5,Energy: -24.133312
# Sweep[r->l]: 2/6, Loc: 4,Energy: -24.156131
# Sweep[r->l]: 2/6, Loc: 3,Energy: -24.175386
# Sweep[r->l]: 2/6, Loc: 2,Energy: -24.189124
# Sweep[r->l]: 2/6, Loc: 1,Energy: -24.196459
# Sweep[r->l]: 2/6, Loc: 0,Energy: -24.234671
# Sweep[l->r]: 2/6, Loc: 0,Energy: -24.240233
# Sweep[l->r]: 2/6, Loc: 1,Energy: -24.243809
# Sweep[l->r]: 2/6, Loc: 2,Energy: -24.257552
# Sweep[l->r]: 2/6, Loc: 3,Energy: -24.270738
# Sweep[l->r]: 2/6, Loc: 4,Energy: -24.284050
# Sweep[l->r]: 2/6, Loc: 5,Energy: -24.297059
# Sweep[l->r]: 2/6, Loc: 6,Energy: -24.309399
# Sweep[l->r]: 2/6, Loc: 7,Energy: -24.321360
# Sweep[l->r]: 2/6, Loc: 8,Energy: -24.333002
# Sweep[l->r]: 2/6, Loc: 9,Energy: -24.343967
# Sweep[l->r]: 2/6, Loc: 10,Energy: -24.354655
# Sweep[l->r]: 2/6, Loc: 11,Energy: -24.364657
# Sweep[l->r]: 2/6, Loc: 12,Energy: -24.373926
# Sweep[l->r]: 2/6, Loc: 13,Energy: -24.382623
# Sweep[l->r]: 2/6, Loc: 14,Energy: -24.390033
# Sweep[l->r]: 2/6, Loc: 15,Energy: -24.396718
# Sweep[l->r]: 2/6, Loc: 16,Energy: -24.402075
# Sweep[l->r]: 2/6, Loc: 17,Energy: -24.406887
# Sweep[l->r]: 2/6, Loc: 18,Energy: -24.485466
# Sweep[r->l]: 3/6, Loc: 18,Energy: -24.504730
# Sweep[r->l]: 3/6, Loc: 17,Energy: -24.514718
# Sweep[r->l]: 3/6, Loc: 16,Energy: -24.522834
# Sweep[r->l]: 3/6, Loc: 15,Energy: -24.530332
# Sweep[r->l]: 3/6, Loc: 14,Energy: -24.537097
# Sweep[r->l]: 3/6, Loc: 13,Energy: -24.543881
# Sweep[r->l]: 3/6, Loc: 12,Energy: -24.550065
# Sweep[r->l]: 3/6, Loc: 11,Energy: -24.555998
# Sweep[r->l]: 3/6, Loc: 10,Energy: -24.561477
# Sweep[r->l]: 3/6, Loc: 9,Energy: -24.566581
# Sweep[r->l]: 3/6, Loc: 8,Energy: -24.571358
# Sweep[r->l]: 3/6, Loc: 7,Energy: -24.575817
# Sweep[r->l]: 3/6, Loc: 6,Energy: -24.580004
# Sweep[r->l]: 3/6, Loc: 5,Energy: -24.583880
# Sweep[r->l]: 3/6, Loc: 4,Energy: -24.587551
# Sweep[r->l]: 3/6, Loc: 3,Energy: -24.590808
# Sweep[r->l]: 3/6, Loc: 2,Energy: -24.593200
# Sweep[r->l]: 3/6, Loc: 1,Energy: -24.595038
# Sweep[r->l]: 3/6, Loc: 0,Energy: -24.597935
# Sweep[l->r]: 3/6, Loc: 0,Energy: -24.598350
# Sweep[l->r]: 3/6, Loc: 1,Energy: -24.599983
# Sweep[l->r]: 3/6, Loc: 2,Energy: -24.602305
# Sweep[l->r]: 3/6, Loc: 3,Energy: -24.605346
# Sweep[l->r]: 3/6, Loc: 4,Energy: -24.608701
# Sweep[l->r]: 3/6, Loc: 5,Energy: -24.611959
# Sweep[l->r]: 3/6, Loc: 6,Energy: -24.615273
# Sweep[l->r]: 3/6, Loc: 7,Energy: -24.618556
# Sweep[l->r]: 3/6, Loc: 8,Energy: -24.621865
# Sweep[l->r]: 3/6, Loc: 9,Energy: -24.625158
# Sweep[l->r]: 3/6, Loc: 10,Energy: -24.628503
# Sweep[l->r]: 3/6, Loc: 11,Energy: -24.631748
# Sweep[l->r]: 3/6, Loc: 12,Energy: -24.634870
# Sweep[l->r]: 3/6, Loc: 13,Energy: -24.637820
# Sweep[l->r]: 3/6, Loc: 14,Energy: -24.640557
# Sweep[l->r]: 3/6, Loc: 15,Energy: -24.643129
# Sweep[l->r]: 3/6, Loc: 16,Energy: -24.645387
# Sweep[l->r]: 3/6, Loc: 17,Energy: -24.648027
# Sweep[l->r]: 3/6, Loc: 18,Energy: -24.657540
# Sweep[r->l]: 4/6, Loc: 18,Energy: -24.659326
# Sweep[r->l]: 4/6, Loc: 17,Energy: -24.663039
# Sweep[r->l]: 4/6, Loc: 16,Energy: -24.665783
# Sweep[r->l]: 4/6, Loc: 15,Energy: -24.668530
# Sweep[r->l]: 4/6, Loc: 14,Energy: -24.671087
# Sweep[r->l]: 4/6, Loc: 13,Energy: -24.673570
# Sweep[r->l]: 4/6, Loc: 12,Energy: -24.675933
# Sweep[r->l]: 4/6, Loc: 11,Energy: -24.678221
# Sweep[r->l]: 4/6, Loc: 10,Energy: -24.680387
# Sweep[r->l]: 4/6, Loc: 9,Energy: -24.682468
# Sweep[r->l]: 4/6, Loc: 8,Energy: -24.684459
# Sweep[r->l]: 4/6, Loc: 7,Energy: -24.686354
# Sweep[r->l]: 4/6, Loc: 6,Energy: -24.688174
# Sweep[r->l]: 4/6, Loc: 5,Energy: -24.689904
# Sweep[r->l]: 4/6, Loc: 4,Energy: -24.691569
# Sweep[r->l]: 4/6, Loc: 3,Energy: -24.693128
# Sweep[r->l]: 4/6, Loc: 2,Energy: -24.694516
# Sweep[r->l]: 4/6, Loc: 1,Energy: -24.696824
# Sweep[r->l]: 4/6, Loc: 0,Energy: -24.700216
# Sweep[l->r]: 4/6, Loc: 0,Energy: -24.701027
# Sweep[l->r]: 4/6, Loc: 1,Energy: -24.703261
# Sweep[l->r]: 4/6, Loc: 2,Energy: -24.704733
# Sweep[l->r]: 4/6, Loc: 3,Energy: -24.706275
# Sweep[l->r]: 4/6, Loc: 4,Energy: -24.707805
# Sweep[l->r]: 4/6, Loc: 5,Energy: -24.709274
# Sweep[l->r]: 4/6, Loc: 6,Energy: -24.710725
# Sweep[l->r]: 4/6, Loc: 7,Energy: -24.712127
# Sweep[l->r]: 4/6, Loc: 8,Energy: -24.713510
# Sweep[l->r]: 4/6, Loc: 9,Energy: -24.714850
# Sweep[l->r]: 4/6, Loc: 10,Energy: -24.716149
# Sweep[l->r]: 4/6, Loc: 11,Energy: -24.717415
# Sweep[l->r]: 4/6, Loc: 12,Energy: -24.718631
# Sweep[l->r]: 4/6, Loc: 13,Energy: -24.719791
# Sweep[l->r]: 4/6, Loc: 14,Energy: -24.720894
# Sweep[l->r]: 4/6, Loc: 15,Energy: -24.721945
# Sweep[l->r]: 4/6, Loc: 16,Energy: -24.722897
# Sweep[l->r]: 4/6, Loc: 17,Energy: -24.724435
# Sweep[l->r]: 4/6, Loc: 18,Energy: -24.727738
# Sweep[r->l]: 5/6, Loc: 18,Energy: -24.728180
# Sweep[r->l]: 5/6, Loc: 17,Energy: -24.729940
# Sweep[r->l]: 5/6, Loc: 16,Energy: -24.731010
# Sweep[r->l]: 5/6, Loc: 15,Energy: -24.732072
# Sweep[r->l]: 5/6, Loc: 14,Energy: -24.733069
# Sweep[r->l]: 5/6, Loc: 13,Energy: -24.734015
# Sweep[r->l]: 5/6, Loc: 12,Energy: -24.734911
# Sweep[r->l]: 5/6, Loc: 11,Energy: -24.735761
# Sweep[r->l]: 5/6, Loc: 10,Energy: -24.736569
# Sweep[r->l]: 5/6, Loc: 9,Energy: -24.737338
# Sweep[r->l]: 5/6, Loc: 8,Energy: -24.738073
# Sweep[r->l]: 5/6, Loc: 7,Energy: -24.738776
# Sweep[r->l]: 5/6, Loc: 6,Energy: -24.739446
# Sweep[r->l]: 5/6, Loc: 5,Energy: -24.740080
# Sweep[r->l]: 5/6, Loc: 4,Energy: -24.740686
# Sweep[r->l]: 5/6, Loc: 3,Energy: -24.741261
# Sweep[r->l]: 5/6, Loc: 2,Energy: -24.741795
# Sweep[r->l]: 5/6, Loc: 1,Energy: -24.744225
# Sweep[r->l]: 5/6, Loc: 0,Energy: -24.745636
# Sweep[l->r]: 5/6, Loc: 0,Energy: -24.746137
# Sweep[l->r]: 5/6, Loc: 1,Energy: -24.747709
# Sweep[l->r]: 5/6, Loc: 2,Energy: -24.748219
# Sweep[l->r]: 5/6, Loc: 3,Energy: -24.748714
# Sweep[l->r]: 5/6, Loc: 4,Energy: -24.749181
# Sweep[l->r]: 5/6, Loc: 5,Energy: -24.749621
# Sweep[l->r]: 5/6, Loc: 6,Energy: -24.750045
# Sweep[l->r]: 5/6, Loc: 7,Energy: -24.750449
# Sweep[l->r]: 5/6, Loc: 8,Energy: -24.750845
# Sweep[l->r]: 5/6, Loc: 9,Energy: -24.751222
# Sweep[l->r]: 5/6, Loc: 10,Energy: -24.751584
# Sweep[l->r]: 5/6, Loc: 11,Energy: -24.751932
# Sweep[l->r]: 5/6, Loc: 12,Energy: -24.752268
# Sweep[l->r]: 5/6, Loc: 13,Energy: -24.752585
# Sweep[l->r]: 5/6, Loc: 14,Energy: -24.752882
# Sweep[l->r]: 5/6, Loc: 15,Energy: -24.753163
# Sweep[l->r]: 5/6, Loc: 16,Energy: -24.753424
# Sweep[l->r]: 5/6, Loc: 17,Energy: -24.754476
# Sweep[l->r]: 5/6, Loc: 18,Energy: -24.755427
# Sweep[r->l]: 6/6, Loc: 18,Energy: -24.755615
# Sweep[r->l]: 6/6, Loc: 17,Energy: -24.756360
# Sweep[r->l]: 6/6, Loc: 16,Energy: -24.756614
# Sweep[r->l]: 6/6, Loc: 15,Energy: -24.756853
# Sweep[r->l]: 6/6, Loc: 14,Energy: -24.757075
# Sweep[r->l]: 6/6, Loc: 13,Energy: -24.757285
# Sweep[r->l]: 6/6, Loc: 12,Energy: -24.757482
# Sweep[r->l]: 6/6, Loc: 11,Energy: -24.757667
# Sweep[r->l]: 6/6, Loc: 10,Energy: -24.757842
# Sweep[r->l]: 6/6, Loc: 9,Energy: -24.758009
# Sweep[r->l]: 6/6, Loc: 8,Energy: -24.758167
# Sweep[r->l]: 6/6, Loc: 7,Energy: -24.758315
# Sweep[r->l]: 6/6, Loc: 6,Energy: -24.758457
# Sweep[r->l]: 6/6, Loc: 5,Energy: -24.758588
# Sweep[r->l]: 6/6, Loc: 4,Energy: -24.758712
# Sweep[r->l]: 6/6, Loc: 3,Energy: -24.758827
# Sweep[r->l]: 6/6, Loc: 2,Energy: -24.758936
# Sweep[r->l]: 6/6, Loc: 1,Energy: -24.760002
# Sweep[r->l]: 6/6, Loc: 0,Energy: -24.760277
# Sweep[l->r]: 6/6, Loc: 0,Energy: -24.760363
# Sweep[l->r]: 6/6, Loc: 1,Energy: -24.760662
# Sweep[l->r]: 6/6, Loc: 2,Energy: -24.760795
# Sweep[l->r]: 6/6, Loc: 3,Energy: -24.760910
# Sweep[l->r]: 6/6, Loc: 4,Energy: -24.761013
# Sweep[l->r]: 6/6, Loc: 5,Energy: -24.761104
# Sweep[l->r]: 6/6, Loc: 6,Energy: -24.761190
# Sweep[l->r]: 6/6, Loc: 7,Energy: -24.761268
# Sweep[l->r]: 6/6, Loc: 8,Energy: -24.761341
# Sweep[l->r]: 6/6, Loc: 9,Energy: -24.761408
# Sweep[l->r]: 6/6, Loc: 10,Energy: -24.761466
# Sweep[l->r]: 6/6, Loc: 11,Energy: -24.761521
# Sweep[l->r]: 6/6, Loc: 12,Energy: -24.761574
# Sweep[l->r]: 6/6, Loc: 13,Energy: -24.761622
# Sweep[l->r]: 6/6, Loc: 14,Energy: -24.761666
# Sweep[l->r]: 6/6, Loc: 15,Energy: -24.761705
# Sweep[l->r]: 6/6, Loc: 16,Energy: -24.761741
# Sweep[l->r]: 6/6, Loc: 17,Energy: -24.762101
# Sweep[l->r]: 6/6, Loc: 18,Energy: -24.762224
# Energy error =  0.000756227219664396

# %% [markdown]
# ## TDVP

# %%
import sys,os
import numpy as np
import cytnx

"""
Author: Hao-Ti Hung
"""

def tdvp1_XXZmodel_dense(J, Jz, hx, hz, A, chi, dt, time_step):

    class OneSiteOp(cytnx.LinOp):
        def __init__(self, L, M, R):
            self.anet = cytnx.Network()
            d = L.shape()[0]
            D1 = L.shape()[2]
            D2 = R.shape()[2]
            cytnx.LinOp.__init__(self, "mv", D1*D2*d, L.dtype(), R.device())
            self.anet.FromString([\
                        "psi: -1,-2,-3",\
                        "L: -4,-1,0",\
                        "R: -6,-3,2",\
                        "M: -4,-6,-2,1",\
                        "TOUT: 0,1;2"])
            self.anet.PutUniTensors(["L","M","R"],[L,M,R])
        def matvec(self, v):
            self.anet.PutUniTensor("psi",v)
            out = self.anet.Launch()
            out.relabels_(v.labels())
            return out

    class ZeroSiteOp(cytnx.LinOp):
        def __init__(self, L, R):
            self.anet = cytnx.Network()
            d = L.shape()[0]
            D1 = L.shape()[2]
            D2 = R.shape()[2]
            cytnx.LinOp.__init__(self, "mv", D1*D2, L.dtype(), R.device())
            self.anet.FromString([\
                        "C: -1,-2",\
                        "L: -3,-1,0",\
                        "R: -3,-2,1",\
                        "TOUT: 0;1"])
            self.anet.PutUniTensors(["L","R"],[L,R])
        def matvec(self, v):
            self.anet.PutUniTensor("C",v)
            out = self.anet.Launch()
            out.relabels_(v.labels())
            return out

    def time_evolve_Lan_f(psi, functArgs, delta):
        L,M,R = functArgs
        L = L.astype(cytnx.Type.ComplexDouble)
        M = M.astype(cytnx.Type.ComplexDouble)
        R = R.astype(cytnx.Type.ComplexDouble)
        op = OneSiteOp(L,M,R)
        exp_iH_v = cytnx.linalg.Lanczos_Exp(op, psi, -1.0j*delta*0.5, 1.0e-8)
        exp_iH_v.relabels_(psi.labels())
        return exp_iH_v

    def time_evolve_Lan_b(psi, functArgs, delta):
        L,R = functArgs
        L = L.astype(cytnx.Type.ComplexDouble)
        R = R.astype(cytnx.Type.ComplexDouble)
        op = ZeroSiteOp(L,R)
        exp_iH_v = cytnx.linalg.Lanczos_Exp(op, psi, 1.0j*delta*0.5, 1.0e-8)
        exp_iH_v.relabels_(psi.labels())
        return exp_iH_v

    def get_energy(A, M):
        N = len(A)
        L0 = cytnx.UniTensor(cytnx.zeros([5,1,1]), rowrank = 0) #Left boundary
        R0 = cytnx.UniTensor(cytnx.zeros([5,1,1]), rowrank = 0) #Right boundary
        L0[0,0,0] = 1.; R0[4,0,0] = 1.
        L = L0
        anet = cytnx.Network()
        anet.FromString(["L: -2,-1,-3",\
                        "A: -1,-4,1",\
                        "M: -2,0,-4,-5",\
                        "A_Conj: -3,-5,2",\
                        "TOUT: 0,1,2"])
        # or you can do: anet = cytnx.Network("L_AMAH.net")
        for p in range(0, N):
            anet.PutUniTensors(["L","A","A_Conj","M"],[L,A[p],A[p].Conj(),M])
            L = anet.Launch()
        E = cytnx.Contract(L, R0).item()
        print('energy:', E)
        return E


    d = 2 #physical dimension
    sx = cytnx.physics.pauli('x').real()
    sy = cytnx.physics.pauli('y')
    sz = cytnx.physics.pauli('z').real()
    sp = (sx+1j*sy).real()
    sm = (sx-1j*sy).real()

    eye = cytnx.eye(d)
    M = cytnx.zeros([5, 5, d, d])
    M[0,0] = M[4,4] = eye
    M[0,4] = hx*sx + hz*sz
    M[1,4] = sp
    M[2,4] = sm
    M[3,4] = sz
    M[0,1] = 0.5*J*sm
    M[0,2] = 0.5*J*sp
    M[0,3] = Jz*sz
    M = cytnx.UniTensor(M,0)

    L0 = cytnx.UniTensor(cytnx.zeros([5,1,1]), rowrank = 0) #Left boundary
    R0 = cytnx.UniTensor(cytnx.zeros([5,1,1]), rowrank = 0) #Right boundary
    L0[0,0,0] = 1.; R0[4,0,0] = 1.

    lbls = [] # List for storing the MPS labels
    Nsites = len(A)
    lbls.append(["0","1","2"]) # store the labels for later convinience.

    for k in range(1,Nsites):
        lbl = [str(2*k),str(2*k+1),str(2*k+2)]
        A[k].relabels_(lbl)
        lbls.append(lbl) # store the labels for later convinience.

    LR = [None for i in range(Nsites+1)]
    LR[0]  = L0
    LR[-1] = R0


    for p in range(Nsites - 1):

        ## Changing to canonical form site by site:
        s, A[p] ,vt = cytnx.linalg.Gesvd(A[p])
        A[p+1] = cytnx.Contract(cytnx.Contract(s,vt),A[p+1])

        ## Calculate enviroments:
        anet = cytnx.Network()
        anet.FromString(["L: -2,-1,-3",\
                        "A: -1,-4,1",\
                        "M: -2,0,-4,-5",\
                        "A_Conj: -3,-5,2",\
                        "TOUT: 0,1,2"])
        # or you can do: anet = cytnx.Network("L_AMAH.net")
        anet.PutUniTensors(["L","A","A_Conj","M"],[LR[p],A[p],A[p].Conj(),M])
        LR[p+1] = anet.Launch()

        # Recover the original MPS labels
        A[p].relabels_(lbls[p])
        A[p+1].relabels_(lbls[p+1])

    As = []
    As.append(A.copy())
    Es = []


    for k in range(1, time_step+1):
        print('time:', k)
        E = get_energy(A, M)
        Es.append(E)

        for p in range(Nsites-1,-1,-1):
            dim_l = A[p].shape()[0]
            dim_r = A[p].shape()[2]
            new_dim = min(dim_l*d,dim_r*d,chi)


            psi = A[p].clone()
            psi = time_evolve_Lan_f(psi, (LR[p],M,LR[p+1]), dt)

            psi.set_rowrank_(1) # maintain rowrank to perform the svd
            s,_,A[p] = cytnx.linalg.Svd_truncate(psi,new_dim)
            A[p].relabels_(lbls[p]); # set the label back to be consistent
            # update LR from right to left:
            anet = cytnx.Network()
            anet.FromString(["R: -2,-1,-3",\
                            "B: 1,-4,-1",\
                            "M: 0,-2,-4,-5",\
                            "B_Conj: 2,-5,-3",\
                            "TOUT: ;0,1,2"])
            # or you can do: anet = cytnx.Network("R_AMAH.net")
            anet.PutUniTensors(["R","B","M","B_Conj"],[LR[p+1],A[p],M,A[p].Conj()])
            old_LR = LR[p].clone()
            if p != 0:
                LR[p] = anet.Launch()
                s = s/s.Norm().item() # normalize s
                C = cytnx.Contract(_, s)
                #C = time_evolve_b(C, (old_LR, LR[p]), dt)
                C = time_evolve_Lan_b(C, (old_LR, LR[p]), dt)

                A[p-1] = cytnx.Contract(A[p-1], C).relabels_(A[p-1].labels())




            print('Sweep[r->l]: %d/%d, Loc: %d' % (k, time_step, p))

        A[0].set_rowrank_(1)
        _,A[0] = cytnx.linalg.Gesvd(A[0],is_U=False, is_vT=True)
        A[0].relabels_(lbls[0]); #set the label back to be consistent


        for p in range(Nsites):
            dim_l = A[p].shape()[0]
            dim_r = A[p].shape()[2]
            new_dim = min(dim_l*d,dim_r*d,chi)

            psi = A[p]
            psi = time_evolve_Lan_f(psi, (LR[p],M,LR[p+1]), dt)

            psi.set_rowrank_(2) # maintain rowrank to perform the svd
            s,A[p],_ = cytnx.linalg.Svd_truncate(psi,new_dim)
            A[p].relabels_(lbls[p]); #set the label back to be consistent
            # update LR from left to right:
            anet = cytnx.Network()
            anet.FromString(["L: -2,-1,-3",\
                            "A: -1,-4,1",\
                            "M: -2,0,-4,-5",\
                            "A_Conj: -3,-5,2",\
                            "TOUT: 0,1,2"])

            anet.PutUniTensors(["L","A","A_Conj","M"],[LR[p],A[p],A[p].Conj(),M])
            old_LR = LR[p+1].clone()


            if p != Nsites - 1:
                LR[p+1] = anet.Launch()
                s = s/s.Norm().item() # normalize s
                C = cytnx.Contract(s, _)
                C = time_evolve_Lan_b(C, (LR[p+1],old_LR), dt)
                A[p+1] = cytnx.Contract(A[p+1], C)
                A[p+1].permute_(['_aux_L', lbls[p+1][1], lbls[p+1][2]])
                A[p+1].relabels_(lbls[p+1])

            print('Sweep[l->r]: %d/%d, Loc: %d' % (k, time_step, p))

        A[-1].set_rowrank_(2)
        _,A[-1] = cytnx.linalg.Gesvd(A[-1],is_U=True,is_vT=False) ## last one.
        A[-1].relabels_(lbls[-1]); #set the label back to be consistent
        As.append(A.copy())
    return As, Es # all time step states

def Local_meas(A, B, Op, site):
    N = len(A)
    l = cytnx.UniTensor(cytnx.eye(1), rowrank = 1)
    anet = cytnx.Network()
    anet.FromString(["l: 0,3",\
                    "A: 0,1,2",\
                    "B: 3,1,4",\
                    "TOUT: 2;4"])
    for i in range(0, N):
        if i != site:
            anet.PutUniTensors(["l","A","B"],[l,A[i],B[i].Conj()])
            l = anet.Launch()
        else:
            tmp = A[i].relabel(1, "_aux_up")
            Op = Op.relabels(["_aux_up", "_aux_low"])
            tmp = cytnx.Contract(tmp, Op)
            tmp.relabel_("_aux_low", A[i].labels()[1])
            tmp.permute_(A[i].labels())
            anet.PutUniTensors(["l","A","B"],[l,tmp,B[i].Conj()])
            l = anet.Launch()

    return l.reshape(1).item()


def prepare_rand_init_MPS(Nsites, chi, d):
    lbls = []
    A = [None for i in range(Nsites)]
    A[0] = cytnx.UniTensor(cytnx.random.normal([1, d, min(chi, d)], 0., 1., seed=0), rowrank = 2)
    A[0].relabels_(["0","1","2"])
    lbls.append(["0","1","2"]) # store the labels for later convinience.

    for k in range(1,Nsites):
        dim1 = A[k-1].shape()[2]; dim2 = d
        dim3 = min(min(chi, A[k-1].shape()[2] * d), d ** (Nsites - k - 1))
        A[k] = cytnx.UniTensor(cytnx.random.normal([dim1, dim2, dim3],0.,1., seed=0), rowrank = 2)

        lbl = [str(2*k),str(2*k+1),str(2*k+2)]
        A[k].relabels_(lbl)
        lbls.append(lbl) # store the labels for later convinience.
    return A


if __name__ == '__main__':
    #prepare random MPS
    Nsites = 7 # Number of sites
    chi = 8 # MPS bond dimension
    d = 2
    MPS_rand = prepare_rand_init_MPS(Nsites, chi, d)

    # simulate ground state by imaginary time evolution by tdvp
    J = 0.0
    Jz = 0.0
    hx = 0.0
    hz = -1.0
    tau = -1.0j
    time_step = 10
    # prepare up state
    As, Es = tdvp1_XXZmodel_dense(J, Jz, hx, hz, MPS_rand, chi, tau, time_step)
    GS = As[time_step - 1]

    # real tiem evoolution
    J = 0.0
    Jz = 0.5
    hx = 0.3
    hz = 3.0
    dt = 0.1
    time_step = 25 # number of DMRG sweeps
    As, Es = tdvp1_XXZmodel_dense(J, Jz, hx, hz, GS, chi, dt, time_step)

    # measure middle site <Sz>
    Sz = cytnx.UniTensor(cytnx.physics.pauli('z').real(), rowrank = 1)
    Szs = []
    mid_site = int(Nsites/2)
    for i in range(0, len(As)):
        Szs.append(Local_meas(As[i], As[i], Sz, mid_site).real)
# Out:
# time: 1
# energy: -25020.430637680023
# Sweep[r->l]: 1/10, Loc: 6
# Sweep[r->l]: 1/10, Loc: 5
# Sweep[r->l]: 1/10, Loc: 4
# Sweep[r->l]: 1/10, Loc: 3
# Sweep[r->l]: 1/10, Loc: 2
# Sweep[r->l]: 1/10, Loc: 1
# Sweep[r->l]: 1/10, Loc: 0
# Sweep[l->r]: 1/10, Loc: 0
# Sweep[l->r]: 1/10, Loc: 1
# Sweep[l->r]: 1/10, Loc: 2
# Sweep[l->r]: 1/10, Loc: 3
# Sweep[l->r]: 1/10, Loc: 4
# Sweep[l->r]: 1/10, Loc: 5
# Sweep[l->r]: 1/10, Loc: 6
# time: 2
# energy: (-5.122713963301477+1.396299209680746e-33j)
# Sweep[r->l]: 2/10, Loc: 6
# Sweep[r->l]: 2/10, Loc: 5
# Sweep[r->l]: 2/10, Loc: 4
# Sweep[r->l]: 2/10, Loc: 3
# Sweep[r->l]: 2/10, Loc: 2
# Sweep[r->l]: 2/10, Loc: 1
# Sweep[r->l]: 2/10, Loc: 0
# Sweep[l->r]: 2/10, Loc: 0
# Sweep[l->r]: 2/10, Loc: 1
# Sweep[l->r]: 2/10, Loc: 2
# Sweep[l->r]: 2/10, Loc: 3
# Sweep[l->r]: 2/10, Loc: 4
# Sweep[l->r]: 2/10, Loc: 5
# Sweep[l->r]: 2/10, Loc: 6
# time: 3
# energy: (-6.709528575760507+4.9078918047823074e-26j)
# Sweep[r->l]: 3/10, Loc: 6
# Sweep[r->l]: 3/10, Loc: 5
# Sweep[r->l]: 3/10, Loc: 4
# Sweep[r->l]: 3/10, Loc: 3
# Sweep[r->l]: 3/10, Loc: 2
# Sweep[r->l]: 3/10, Loc: 1
# Sweep[r->l]: 3/10, Loc: 0
# Sweep[l->r]: 3/10, Loc: 0
# Sweep[l->r]: 3/10, Loc: 1
# Sweep[l->r]: 3/10, Loc: 2
# Sweep[l->r]: 3/10, Loc: 3
# Sweep[l->r]: 3/10, Loc: 4
# Sweep[l->r]: 3/10, Loc: 5
# Sweep[l->r]: 3/10, Loc: 6
# time: 4
# energy: (-6.993804008645722-4.244328300254133e-31j)
# Sweep[r->l]: 4/10, Loc: 6
# Sweep[r->l]: 4/10, Loc: 5
# Sweep[r->l]: 4/10, Loc: 4
# Sweep[r->l]: 4/10, Loc: 3
# Sweep[r->l]: 4/10, Loc: 2
# Sweep[r->l]: 4/10, Loc: 1
# Sweep[r->l]: 4/10, Loc: 0
# Sweep[l->r]: 4/10, Loc: 0
# Sweep[l->r]: 4/10, Loc: 1
# Sweep[l->r]: 4/10, Loc: 2
# Sweep[l->r]: 4/10, Loc: 3
# Sweep[l->r]: 4/10, Loc: 4
# Sweep[l->r]: 4/10, Loc: 5
# Sweep[l->r]: 4/10, Loc: 6
# time: 5
# energy: (-6.999886173024435+2.2123850605956158e-27j)
# Sweep[r->l]: 5/10, Loc: 6
# Sweep[r->l]: 5/10, Loc: 5
# Sweep[r->l]: 5/10, Loc: 4
# Sweep[r->l]: 5/10, Loc: 3
# Sweep[r->l]: 5/10, Loc: 2
# Sweep[r->l]: 5/10, Loc: 1
# Sweep[r->l]: 5/10, Loc: 0
# Sweep[l->r]: 5/10, Loc: 0
# Sweep[l->r]: 5/10, Loc: 1
# Sweep[l->r]: 5/10, Loc: 2
# Sweep[l->r]: 5/10, Loc: 3
# Sweep[l->r]: 5/10, Loc: 4
# Sweep[l->r]: 5/10, Loc: 5
# Sweep[l->r]: 5/10, Loc: 6
# time: 6
# energy: (-6.9999979150708285+8.427206916737675e-28j)
# Sweep[r->l]: 6/10, Loc: 6
# Sweep[r->l]: 6/10, Loc: 5
# Sweep[r->l]: 6/10, Loc: 4
# Sweep[r->l]: 6/10, Loc: 3
# Sweep[r->l]: 6/10, Loc: 2
# Sweep[r->l]: 6/10, Loc: 1
# Sweep[r->l]: 6/10, Loc: 0
# Sweep[l->r]: 6/10, Loc: 0
# Sweep[l->r]: 6/10, Loc: 1
# Sweep[l->r]: 6/10, Loc: 2
# Sweep[l->r]: 6/10, Loc: 3
# Sweep[l->r]: 6/10, Loc: 4
# Sweep[l->r]: 6/10, Loc: 5
# Sweep[l->r]: 6/10, Loc: 6
# time: 7
# energy: (-6.999999961813102-1.221365066902109e-28j)
# Sweep[r->l]: 7/10, Loc: 6
# Sweep[r->l]: 7/10, Loc: 5
# Sweep[r->l]: 7/10, Loc: 4
# Sweep[r->l]: 7/10, Loc: 3
# Sweep[r->l]: 7/10, Loc: 2
# Sweep[r->l]: 7/10, Loc: 1
# Sweep[r->l]: 7/10, Loc: 0
# Sweep[l->r]: 7/10, Loc: 0
# Sweep[l->r]: 7/10, Loc: 1
# Sweep[l->r]: 7/10, Loc: 2
# Sweep[l->r]: 7/10, Loc: 3
# Sweep[l->r]: 7/10, Loc: 4
# Sweep[l->r]: 7/10, Loc: 5
# Sweep[l->r]: 7/10, Loc: 6
# time: 8
# energy: (-6.999999999298906+1.8447353605067864e-27j)
# Sweep[r->l]: 8/10, Loc: 6
# Sweep[r->l]: 8/10, Loc: 5
# Sweep[r->l]: 8/10, Loc: 4
# Sweep[r->l]: 8/10, Loc: 3
# Sweep[r->l]: 8/10, Loc: 2
# Sweep[r->l]: 8/10, Loc: 1
# Sweep[r->l]: 8/10, Loc: 0
# Sweep[l->r]: 8/10, Loc: 0
# Sweep[l->r]: 8/10, Loc: 1
# Sweep[l->r]: 8/10, Loc: 2
# Sweep[l->r]: 8/10, Loc: 3
# Sweep[l->r]: 8/10, Loc: 4
# Sweep[l->r]: 8/10, Loc: 5
# Sweep[l->r]: 8/10, Loc: 6
# time: 9
# energy: (-6.999999999985944+9.742340162157872e-27j)
# Sweep[r->l]: 9/10, Loc: 6
# Sweep[r->l]: 9/10, Loc: 5
# Sweep[r->l]: 9/10, Loc: 4
# Sweep[r->l]: 9/10, Loc: 3
# Sweep[r->l]: 9/10, Loc: 2
# Sweep[r->l]: 9/10, Loc: 1
# Sweep[r->l]: 9/10, Loc: 0
# Sweep[l->r]: 9/10, Loc: 0
# Sweep[l->r]: 9/10, Loc: 1
# Sweep[l->r]: 9/10, Loc: 2
# Sweep[l->r]: 9/10, Loc: 3
# Sweep[l->r]: 9/10, Loc: 4
# Sweep[l->r]: 9/10, Loc: 5
# Sweep[l->r]: 9/10, Loc: 6
# time: 10
# energy: (-6.999999999851378+1.0254162550910873e-26j)
# Sweep[r->l]: 10/10, Loc: 6
# Sweep[r->l]: 10/10, Loc: 5
# Sweep[r->l]: 10/10, Loc: 4
# Sweep[r->l]: 10/10, Loc: 3
# Sweep[r->l]: 10/10, Loc: 2
# Sweep[r->l]: 10/10, Loc: 1
# Sweep[r->l]: 10/10, Loc: 0
# Sweep[l->r]: 10/10, Loc: 0
# Sweep[l->r]: 10/10, Loc: 1
# Sweep[l->r]: 10/10, Loc: 2
# Sweep[l->r]: 10/10, Loc: 3
# Sweep[l->r]: 10/10, Loc: 4
# Sweep[l->r]: 10/10, Loc: 5
# Sweep[l->r]: 10/10, Loc: 6
# time: 1
# energy: (23.999999992952414-3.705769144237564e-22j)
# Sweep[r->l]: 1/25, Loc: 6
# Sweep[r->l]: 1/25, Loc: 5
# Sweep[r->l]: 1/25, Loc: 4
# Sweep[r->l]: 1/25, Loc: 3
# Sweep[r->l]: 1/25, Loc: 2
# Sweep[r->l]: 1/25, Loc: 1
# Sweep[r->l]: 1/25, Loc: 0
# Sweep[l->r]: 1/25, Loc: 0
# Sweep[l->r]: 1/25, Loc: 1
# Sweep[l->r]: 1/25, Loc: 2
# Sweep[l->r]: 1/25, Loc: 3
# Sweep[l->r]: 1/25, Loc: 4
# Sweep[l->r]: 1/25, Loc: 5
# Sweep[l->r]: 1/25, Loc: 6
# time: 2
# energy: (23.99999999295226-6.135716934529967e-15j)
# Sweep[r->l]: 2/25, Loc: 6
# Sweep[r->l]: 2/25, Loc: 5
# Sweep[r->l]: 2/25, Loc: 4
# Sweep[r->l]: 2/25, Loc: 3
# Sweep[r->l]: 2/25, Loc: 2
# Sweep[r->l]: 2/25, Loc: 1
# Sweep[r->l]: 2/25, Loc: 0
# Sweep[l->r]: 2/25, Loc: 0
# Sweep[l->r]: 2/25, Loc: 1
# Sweep[l->r]: 2/25, Loc: 2
# Sweep[l->r]: 2/25, Loc: 3
# Sweep[l->r]: 2/25, Loc: 4
# Sweep[l->r]: 2/25, Loc: 5
# Sweep[l->r]: 2/25, Loc: 6
# time: 3
# energy: (23.99999999295203-3.2803620930721422e-15j)
# Sweep[r->l]: 3/25, Loc: 6
# Sweep[r->l]: 3/25, Loc: 5
# Sweep[r->l]: 3/25, Loc: 4
# Sweep[r->l]: 3/25, Loc: 3
# Sweep[r->l]: 3/25, Loc: 2
# Sweep[r->l]: 3/25, Loc: 1
# Sweep[r->l]: 3/25, Loc: 0
# Sweep[l->r]: 3/25, Loc: 0
# Sweep[l->r]: 3/25, Loc: 1
# Sweep[l->r]: 3/25, Loc: 2
# Sweep[l->r]: 3/25, Loc: 3
# Sweep[l->r]: 3/25, Loc: 4
# Sweep[l->r]: 3/25, Loc: 5
# Sweep[l->r]: 3/25, Loc: 6
# time: 4
# energy: (23.999999992951793+1.932481952238163e-15j)
# Sweep[r->l]: 4/25, Loc: 6
# Sweep[r->l]: 4/25, Loc: 5
# Sweep[r->l]: 4/25, Loc: 4
# Sweep[r->l]: 4/25, Loc: 3
# Sweep[r->l]: 4/25, Loc: 2
# Sweep[r->l]: 4/25, Loc: 1
# Sweep[r->l]: 4/25, Loc: 0
# Sweep[l->r]: 4/25, Loc: 0
# Sweep[l->r]: 4/25, Loc: 1
# Sweep[l->r]: 4/25, Loc: 2
# Sweep[l->r]: 4/25, Loc: 3
# Sweep[l->r]: 4/25, Loc: 4
# Sweep[l->r]: 4/25, Loc: 5
# Sweep[l->r]: 4/25, Loc: 6
# time: 5
# energy: (23.999999992951643-4.299512135208516e-15j)
# Sweep[r->l]: 5/25, Loc: 6
# Sweep[r->l]: 5/25, Loc: 5
# Sweep[r->l]: 5/25, Loc: 4
# Sweep[r->l]: 5/25, Loc: 3
# Sweep[r->l]: 5/25, Loc: 2
# Sweep[r->l]: 5/25, Loc: 1
# Sweep[r->l]: 5/25, Loc: 0
# Sweep[l->r]: 5/25, Loc: 0
# Sweep[l->r]: 5/25, Loc: 1
# Sweep[l->r]: 5/25, Loc: 2
# Sweep[l->r]: 5/25, Loc: 3
# Sweep[l->r]: 5/25, Loc: 4
# Sweep[l->r]: 5/25, Loc: 5
# Sweep[l->r]: 5/25, Loc: 6
# time: 6
# energy: (23.999999992951558-4.023691102528204e-15j)
# Sweep[r->l]: 6/25, Loc: 6
# Sweep[r->l]: 6/25, Loc: 5
# Sweep[r->l]: 6/25, Loc: 4
# Sweep[r->l]: 6/25, Loc: 3
# Sweep[r->l]: 6/25, Loc: 2
# Sweep[r->l]: 6/25, Loc: 1
# Sweep[r->l]: 6/25, Loc: 0
# Sweep[l->r]: 6/25, Loc: 0
# Sweep[l->r]: 6/25, Loc: 1
# Sweep[l->r]: 6/25, Loc: 2
# Sweep[l->r]: 6/25, Loc: 3
# Sweep[l->r]: 6/25, Loc: 4
# Sweep[l->r]: 6/25, Loc: 5
# Sweep[l->r]: 6/25, Loc: 6
# time: 7
# energy: (23.99999999295141-6.175615574477433e-16j)
# Sweep[r->l]: 7/25, Loc: 6
# Sweep[r->l]: 7/25, Loc: 5
# Sweep[r->l]: 7/25, Loc: 4
# Sweep[r->l]: 7/25, Loc: 3
# Sweep[r->l]: 7/25, Loc: 2
# Sweep[r->l]: 7/25, Loc: 1
# Sweep[r->l]: 7/25, Loc: 0
# Sweep[l->r]: 7/25, Loc: 0
# Sweep[l->r]: 7/25, Loc: 1
# Sweep[l->r]: 7/25, Loc: 2
# Sweep[l->r]: 7/25, Loc: 3
# Sweep[l->r]: 7/25, Loc: 4
# Sweep[l->r]: 7/25, Loc: 5
# Sweep[l->r]: 7/25, Loc: 6
# time: 8
# energy: (23.99999999295119-1.3079815008865125e-15j)
# Sweep[r->l]: 8/25, Loc: 6
# Sweep[r->l]: 8/25, Loc: 5
# Sweep[r->l]: 8/25, Loc: 4
# Sweep[r->l]: 8/25, Loc: 3
# Sweep[r->l]: 8/25, Loc: 2
# Sweep[r->l]: 8/25, Loc: 1
# Sweep[r->l]: 8/25, Loc: 0
# Sweep[l->r]: 8/25, Loc: 0
# Sweep[l->r]: 8/25, Loc: 1
# Sweep[l->r]: 8/25, Loc: 2
# Sweep[l->r]: 8/25, Loc: 3
# Sweep[l->r]: 8/25, Loc: 4
# Sweep[l->r]: 8/25, Loc: 5
# Sweep[l->r]: 8/25, Loc: 6
# time: 9
# energy: (23.99999999295105-2.2065682614424986e-15j)
# Sweep[r->l]: 9/25, Loc: 6
# Sweep[r->l]: 9/25, Loc: 5
# Sweep[r->l]: 9/25, Loc: 4
# Sweep[r->l]: 9/25, Loc: 3
# Sweep[r->l]: 9/25, Loc: 2
# Sweep[r->l]: 9/25, Loc: 1
# Sweep[r->l]: 9/25, Loc: 0
# Sweep[l->r]: 9/25, Loc: 0
# Sweep[l->r]: 9/25, Loc: 1
# Sweep[l->r]: 9/25, Loc: 2
# Sweep[l->r]: 9/25, Loc: 3
# Sweep[l->r]: 9/25, Loc: 4
# Sweep[l->r]: 9/25, Loc: 5
# Sweep[l->r]: 9/25, Loc: 6
# time: 10
# energy: (23.999999992950805+2.0197602271232462e-15j)
# Sweep[r->l]: 10/25, Loc: 6
# Sweep[r->l]: 10/25, Loc: 5
# Sweep[r->l]: 10/25, Loc: 4
# Sweep[r->l]: 10/25, Loc: 3
# Sweep[r->l]: 10/25, Loc: 2
# Sweep[r->l]: 10/25, Loc: 1
# Sweep[r->l]: 10/25, Loc: 0
# Sweep[l->r]: 10/25, Loc: 0
# Sweep[l->r]: 10/25, Loc: 1
# Sweep[l->r]: 10/25, Loc: 2
# Sweep[l->r]: 10/25, Loc: 3
# Sweep[l->r]: 10/25, Loc: 4
# Sweep[l->r]: 10/25, Loc: 5
# Sweep[l->r]: 10/25, Loc: 6
# time: 11
# energy: (23.999999992950613-5.7592819402429996e-15j)
# Sweep[r->l]: 11/25, Loc: 6
# Sweep[r->l]: 11/25, Loc: 5
# Sweep[r->l]: 11/25, Loc: 4
# Sweep[r->l]: 11/25, Loc: 3
# Sweep[r->l]: 11/25, Loc: 2
# Sweep[r->l]: 11/25, Loc: 1
# Sweep[r->l]: 11/25, Loc: 0
# Sweep[l->r]: 11/25, Loc: 0
# Sweep[l->r]: 11/25, Loc: 1
# Sweep[l->r]: 11/25, Loc: 2
# Sweep[l->r]: 11/25, Loc: 3
# Sweep[l->r]: 11/25, Loc: 4
# Sweep[l->r]: 11/25, Loc: 5
# Sweep[l->r]: 11/25, Loc: 6
# time: 12
# energy: (23.999999992950393+3.630776235219457e-15j)
# Sweep[r->l]: 12/25, Loc: 6
# Sweep[r->l]: 12/25, Loc: 5
# Sweep[r->l]: 12/25, Loc: 4
# Sweep[r->l]: 12/25, Loc: 3
# Sweep[r->l]: 12/25, Loc: 2
# Sweep[r->l]: 12/25, Loc: 1
# Sweep[r->l]: 12/25, Loc: 0
# Sweep[l->r]: 12/25, Loc: 0
# Sweep[l->r]: 12/25, Loc: 1
# Sweep[l->r]: 12/25, Loc: 2
# Sweep[l->r]: 12/25, Loc: 3
# Sweep[l->r]: 12/25, Loc: 4
# Sweep[l->r]: 12/25, Loc: 5
# Sweep[l->r]: 12/25, Loc: 6
# time: 13
# energy: (23.99999999295022-1.0894063429134349e-15j)
# Sweep[r->l]: 13/25, Loc: 6
# Sweep[r->l]: 13/25, Loc: 5
# Sweep[r->l]: 13/25, Loc: 4
# Sweep[r->l]: 13/25, Loc: 3
# Sweep[r->l]: 13/25, Loc: 2
# Sweep[r->l]: 13/25, Loc: 1
# Sweep[r->l]: 13/25, Loc: 0
# Sweep[l->r]: 13/25, Loc: 0
# Sweep[l->r]: 13/25, Loc: 1
# Sweep[l->r]: 13/25, Loc: 2
# Sweep[l->r]: 13/25, Loc: 3
# Sweep[l->r]: 13/25, Loc: 4
# Sweep[l->r]: 13/25, Loc: 5
# Sweep[l->r]: 13/25, Loc: 6
# time: 14
# energy: (23.999999992950052-3.5605199344423966e-16j)
# Sweep[r->l]: 14/25, Loc: 6
# Sweep[r->l]: 14/25, Loc: 5
# Sweep[r->l]: 14/25, Loc: 4
# Sweep[r->l]: 14/25, Loc: 3
# Sweep[r->l]: 14/25, Loc: 2
# Sweep[r->l]: 14/25, Loc: 1
# Sweep[r->l]: 14/25, Loc: 0
# Sweep[l->r]: 14/25, Loc: 0
# Sweep[l->r]: 14/25, Loc: 1
# Sweep[l->r]: 14/25, Loc: 2
# Sweep[l->r]: 14/25, Loc: 3
# Sweep[l->r]: 14/25, Loc: 4
# Sweep[l->r]: 14/25, Loc: 5
# Sweep[l->r]: 14/25, Loc: 6
# time: 15
# energy: (23.999999992949924+2.8657631823136853e-15j)
# Sweep[r->l]: 15/25, Loc: 6
# Sweep[r->l]: 15/25, Loc: 5
# Sweep[r->l]: 15/25, Loc: 4
# Sweep[r->l]: 15/25, Loc: 3
# Sweep[r->l]: 15/25, Loc: 2
# Sweep[r->l]: 15/25, Loc: 1
# Sweep[r->l]: 15/25, Loc: 0
# Sweep[l->r]: 15/25, Loc: 0
# Sweep[l->r]: 15/25, Loc: 1
# Sweep[l->r]: 15/25, Loc: 2
# Sweep[l->r]: 15/25, Loc: 3
# Sweep[l->r]: 15/25, Loc: 4
# Sweep[l->r]: 15/25, Loc: 5
# Sweep[l->r]: 15/25, Loc: 6
# time: 16
# energy: (23.999999992949682-1.6844164951734797e-15j)
# Sweep[r->l]: 16/25, Loc: 6
# Sweep[r->l]: 16/25, Loc: 5
# Sweep[r->l]: 16/25, Loc: 4
# Sweep[r->l]: 16/25, Loc: 3
# Sweep[r->l]: 16/25, Loc: 2
# Sweep[r->l]: 16/25, Loc: 1
# Sweep[r->l]: 16/25, Loc: 0
# Sweep[l->r]: 16/25, Loc: 0
# Sweep[l->r]: 16/25, Loc: 1
# Sweep[l->r]: 16/25, Loc: 2
# Sweep[l->r]: 16/25, Loc: 3
# Sweep[l->r]: 16/25, Loc: 4
# Sweep[l->r]: 16/25, Loc: 5
# Sweep[l->r]: 16/25, Loc: 6
# time: 17
# energy: (23.999999992949533-1.3513495877859327e-15j)
# Sweep[r->l]: 17/25, Loc: 6
# Sweep[r->l]: 17/25, Loc: 5
# Sweep[r->l]: 17/25, Loc: 4
# Sweep[r->l]: 17/25, Loc: 3
# Sweep[r->l]: 17/25, Loc: 2
# Sweep[r->l]: 17/25, Loc: 1
# Sweep[r->l]: 17/25, Loc: 0
# Sweep[l->r]: 17/25, Loc: 0
# Sweep[l->r]: 17/25, Loc: 1
# Sweep[l->r]: 17/25, Loc: 2
# Sweep[l->r]: 17/25, Loc: 3
# Sweep[l->r]: 17/25, Loc: 4
# Sweep[l->r]: 17/25, Loc: 5
# Sweep[l->r]: 17/25, Loc: 6
# time: 18
# energy: (23.99999999294931-2.624636619152909e-15j)
# Sweep[r->l]: 18/25, Loc: 6
# Sweep[r->l]: 18/25, Loc: 5
# Sweep[r->l]: 18/25, Loc: 4
# Sweep[r->l]: 18/25, Loc: 3
# Sweep[r->l]: 18/25, Loc: 2
# Sweep[r->l]: 18/25, Loc: 1
# Sweep[r->l]: 18/25, Loc: 0
# Sweep[l->r]: 18/25, Loc: 0
# Sweep[l->r]: 18/25, Loc: 1
# Sweep[l->r]: 18/25, Loc: 2
# Sweep[l->r]: 18/25, Loc: 3
# Sweep[l->r]: 18/25, Loc: 4
# Sweep[l->r]: 18/25, Loc: 5
# Sweep[l->r]: 18/25, Loc: 6
# time: 19
# energy: (23.999999992949167+2.5195774286390638e-15j)
# Sweep[r->l]: 19/25, Loc: 6
# Sweep[r->l]: 19/25, Loc: 5
# Sweep[r->l]: 19/25, Loc: 4
# Sweep[r->l]: 19/25, Loc: 3
# Sweep[r->l]: 19/25, Loc: 2
# Sweep[r->l]: 19/25, Loc: 1
# Sweep[r->l]: 19/25, Loc: 0
# Sweep[l->r]: 19/25, Loc: 0
# Sweep[l->r]: 19/25, Loc: 1
# Sweep[l->r]: 19/25, Loc: 2
# Sweep[l->r]: 19/25, Loc: 3
# Sweep[l->r]: 19/25, Loc: 4
# Sweep[l->r]: 19/25, Loc: 5
# Sweep[l->r]: 19/25, Loc: 6
# time: 20
# energy: (23.999999992949114+4.430483757644765e-15j)
# Sweep[r->l]: 20/25, Loc: 6
# Sweep[r->l]: 20/25, Loc: 5
# Sweep[r->l]: 20/25, Loc: 4
# Sweep[r->l]: 20/25, Loc: 3
# Sweep[r->l]: 20/25, Loc: 2
# Sweep[r->l]: 20/25, Loc: 1
# Sweep[r->l]: 20/25, Loc: 0
# Sweep[l->r]: 20/25, Loc: 0
# Sweep[l->r]: 20/25, Loc: 1
# Sweep[l->r]: 20/25, Loc: 2
# Sweep[l->r]: 20/25, Loc: 3
# Sweep[l->r]: 20/25, Loc: 4
# Sweep[l->r]: 20/25, Loc: 5
# Sweep[l->r]: 20/25, Loc: 6
# time: 21
# energy: (23.999999992948904-1.1431827706687159e-15j)
# Sweep[r->l]: 21/25, Loc: 6
# Sweep[r->l]: 21/25, Loc: 5
# Sweep[r->l]: 21/25, Loc: 4
# Sweep[r->l]: 21/25, Loc: 3
# Sweep[r->l]: 21/25, Loc: 2
# Sweep[r->l]: 21/25, Loc: 1
# Sweep[r->l]: 21/25, Loc: 0
# Sweep[l->r]: 21/25, Loc: 0
# Sweep[l->r]: 21/25, Loc: 1
# Sweep[l->r]: 21/25, Loc: 2
# Sweep[l->r]: 21/25, Loc: 3
# Sweep[l->r]: 21/25, Loc: 4
# Sweep[l->r]: 21/25, Loc: 5
# Sweep[l->r]: 21/25, Loc: 6
# time: 22
# energy: (23.999999992948755-2.3158558404290375e-15j)
# Sweep[r->l]: 22/25, Loc: 6
# Sweep[r->l]: 22/25, Loc: 5
# Sweep[r->l]: 22/25, Loc: 4
# Sweep[r->l]: 22/25, Loc: 3
# Sweep[r->l]: 22/25, Loc: 2
# Sweep[r->l]: 22/25, Loc: 1
# Sweep[r->l]: 22/25, Loc: 0
# Sweep[l->r]: 22/25, Loc: 0
# Sweep[l->r]: 22/25, Loc: 1
# Sweep[l->r]: 22/25, Loc: 2
# Sweep[l->r]: 22/25, Loc: 3
# Sweep[l->r]: 22/25, Loc: 4
# Sweep[l->r]: 22/25, Loc: 5
# Sweep[l->r]: 22/25, Loc: 6
# time: 23
# energy: (23.999999992948606-2.6571626843274743e-15j)
# Sweep[r->l]: 23/25, Loc: 6
# Sweep[r->l]: 23/25, Loc: 5
# Sweep[r->l]: 23/25, Loc: 4
# Sweep[r->l]: 23/25, Loc: 3
# Sweep[r->l]: 23/25, Loc: 2
# Sweep[r->l]: 23/25, Loc: 1
# Sweep[r->l]: 23/25, Loc: 0
# Sweep[l->r]: 23/25, Loc: 0
# Sweep[l->r]: 23/25, Loc: 1
# Sweep[l->r]: 23/25, Loc: 2
# Sweep[l->r]: 23/25, Loc: 3
# Sweep[l->r]: 23/25, Loc: 4
# Sweep[l->r]: 23/25, Loc: 5
# Sweep[l->r]: 23/25, Loc: 6
# time: 24
# energy: (23.999999992948464+7.858297346174936e-16j)
# Sweep[r->l]: 24/25, Loc: 6
# Sweep[r->l]: 24/25, Loc: 5
# Sweep[r->l]: 24/25, Loc: 4
# Sweep[r->l]: 24/25, Loc: 3
# Sweep[r->l]: 24/25, Loc: 2
# Sweep[r->l]: 24/25, Loc: 1
# Sweep[r->l]: 24/25, Loc: 0
# Sweep[l->r]: 24/25, Loc: 0
# Sweep[l->r]: 24/25, Loc: 1
# Sweep[l->r]: 24/25, Loc: 2
# Sweep[l->r]: 24/25, Loc: 3
# Sweep[l->r]: 24/25, Loc: 4
# Sweep[l->r]: 24/25, Loc: 5
# Sweep[l->r]: 24/25, Loc: 6
# time: 25
# energy: (23.999999992948265+2.05911676598447e-15j)
# Sweep[r->l]: 25/25, Loc: 6
# Sweep[r->l]: 25/25, Loc: 5
# Sweep[r->l]: 25/25, Loc: 4
# Sweep[r->l]: 25/25, Loc: 3
# Sweep[r->l]: 25/25, Loc: 2
# Sweep[r->l]: 25/25, Loc: 1
# Sweep[r->l]: 25/25, Loc: 0
# Sweep[l->r]: 25/25, Loc: 0
# Sweep[l->r]: 25/25, Loc: 1
# Sweep[l->r]: 25/25, Loc: 2
# Sweep[l->r]: 25/25, Loc: 3
# Sweep[l->r]: 25/25, Loc: 4
# Sweep[l->r]: 25/25, Loc: 5
# Sweep[l->r]: 25/25, Loc: 6

# %%
plt.plot(Szs)
plt.xlabel('time step')
plt.ylabel('<Sz>')
plt.show()
